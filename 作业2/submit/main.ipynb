# %% [markdown]
# ## 1.实验教程
# 第一部分仅作为实验教程，同学们可以直接运行，用于快速熟悉实验环境和基本操作。

# %% [markdown]
# ### 1.1 实验背景介绍
# LeNet5 + MNIST 被誉为深度学习领域的 “Hello world”。本教程主要介绍使用 paddlepaddle 在 MNIST 手写数字数据集上开发和训练一个 LeNet5 模型，并验证模型精度。
# 通过以上学习，使用 paddlepaddle 深度学习框架完成对10种动物进行分类。

# %% [markdown]
# ### 1.2  实验示例：手写数字识别
#
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/4c7206c4ba444963981b43118627fcbf1e67f94840d144bfb7b00265cf63dcfd)

# %%
#导入需要的包
import numpy as np
import paddle as paddle
import paddle.fluid as fluid
from PIL import Image
import matplotlib.pyplot as plt
import os
from paddle.fluid.dygraph import Linear
print("本教程基于Paddle的版本号为:"+paddle.__version__)
# Out:
# 本教程基于Paddle的版本号为:2.0.2

# %% [markdown]
# #### **Step1：准备数据。**
#
# (1)数据集介绍
#
# MNIST数据集包含60000个训练集和10000测试数据集。分为图片和标签，图片是28*28的像素矩阵，标签为0~9共10个数字。
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/fc73217ae57f451a89badc801a903bb742e42eabd9434ecc8089efe19a66c076)
#
# (2)transform函数是定义了一个归一化标准化的标准
#
# (3)train_dataset和test_dataset
#
# - paddle.vision.datasets.MNIST()中的mode='train'和mode='test'分别用于获取mnist训练集和测试集
#
# - transform=transform参数则为归一化标准

# %% [markdown]
# 导入数据集Compose的作用是将用于数据集预处理的接口以列表的方式进行组合。
#
# 导入数据集Normalize的作用是图像归一化处理，支持两种方式：
# - 用统一的均值和标准差值对图像的每个通道进行归一化处理；
# - 对每个通道指定不同的均值和标准差值进行归一化处理。

# %%
from paddle.vision.transforms import Compose, Normalize
transform = Compose([Normalize(mean=[127.5],std=[127.5],data_format='CHW')])
# 使用transform对数据集做归一化
print('下载并加载训练数据')
train_dataset = paddle.vision.datasets.MNIST(mode='train', transform=transform)
test_dataset = paddle.vision.datasets.MNIST(mode='test', transform=transform)
print('加载完成')
# Out:
# 下载并加载训练数据
# Cache file /home/aistudio/.cache/paddle/dataset/mnist/train-images-idx3-ubyte.gz not found, downloading https://dataset.bj.bcebos.com/mnist/train-images-idx3-ubyte.gz
# Begin to download
#
# Download finished
# Cache file /home/aistudio/.cache/paddle/dataset/mnist/train-labels-idx1-ubyte.gz not found, downloading https://dataset.bj.bcebos.com/mnist/train-labels-idx1-ubyte.gz
# Begin to download
# ........
# Download finished
# Cache file /home/aistudio/.cache/paddle/dataset/mnist/t10k-images-idx3-ubyte.gz not found, downloading https://dataset.bj.bcebos.com/mnist/t10k-images-idx3-ubyte.gz
# Begin to download
#
# Download finished
# Cache file /home/aistudio/.cache/paddle/dataset/mnist/t10k-labels-idx1-ubyte.gz not found, downloading https://dataset.bj.bcebos.com/mnist/t10k-labels-idx1-ubyte.gz
# Begin to download
# ..
# Download finished
# 加载完成

# %%
#看看数据集中的图片是什么样子的
train_data0, train_label_0 = train_dataset[0][0],train_dataset[0][1]
train_data0 = train_data0.reshape([28,28])
plt.figure(figsize=(2,2))
print(plt.imshow(train_data0, cmap=plt.cm.binary))
print('train_data0 的标签为: ' + str(train_label_0))
# Out:
# AxesImage(25,22;155x154)
# train_data0 的标签为: [5]
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:2349: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   if isinstance(obj, collections.Iterator):
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:2366: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   return list(data) if isinstance(data, collections.MappingView) else data
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/image.py:425: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   a_min = np.asscalar(a_min.astype(scaled_dtype))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/image.py:426: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   a_max = np.asscalar(a_max.astype(scaled_dtype))

# %% [markdown]
# #### **Step2.网络配置**
# 以下的代码定义一个简单的多层感知器，一共有三层，两个shape为[100,100]的隐藏层和shape为[100,10]的输出层，因为MNIST数据集是手写0到9的灰度图像，类别有10个，所以最后的输出维度是10。激活函数是Softmax。
#
# 多层感知器的结构是：输入层-->>隐藏层-->>隐藏层-->>输出层。
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/cb69f928778c4299b75814179607a89eea770bdc409d4e08a87e2975cb96b19b)

# %%
# 定义多层感知器 
# 动态图定义多层感知器
class mnist(paddle.nn.Layer):
    def __init__(self):
        super(mnist,self).__init__()
        self.fc1 = paddle.fluid.dygraph.Linear(input_dim=28*28, output_dim=100, act='relu')
        self.fc2 = paddle.fluid.dygraph.Linear(input_dim=100, output_dim=100, act='relu')
        self.fc3 = paddle.fluid.dygraph.Linear(input_dim=100, output_dim=10,act="softmax")

    def forward(self, input_):
        x = fluid.layers.reshape(input_, [input_.shape[0], -1])
        x = self.fc1(x)
        x = self.fc2(x)
        y = self.fc3(x)
        return y

# %%
from paddle.metric import Accuracy

# 用Model封装模型
model = paddle.Model(mnist())   

# 定义损失函数
optim = paddle.optimizer.Adam(learning_rate=0.001, parameters=model.parameters())

# 配置模型
model.prepare(optim,paddle.nn.CrossEntropyLoss(),Accuracy())

# 训练保存并验证模型
model.fit(train_dataset,test_dataset,epochs=2,batch_size=64,save_dir='multilayer_perceptron',verbose=1)
# Out:
# W0417 20:36:40.204187   267 device_context.cc:362] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 12.0, Runtime API Version: 10.1
# W0417 20:36:40.208063   267 device_context.cc:372] device: 0, cuDNN Version: 7.6.
# The loss value printed in the log is the current step, and the metric is the average value of previous step.
# Epoch 1/2
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dataloader/dataloader_iter.py:89: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if isinstance(slot[0], (np.ndarray, np.bool, numbers.Number)):
# step  20/938 [..............................] - loss: 1.8959 - acc: 0.4641 - ETA: 30s - 33ms/step
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/layers/utils.py:77: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   return (isinstance(seq, collections.Sequence) and
# step 938/938 [==============================] - loss: 1.5094 - acc: 0.7923 - 7ms/step
# save checkpoint at /home/aistudio/multilayer_perceptron/0
# Eval begin...
# The loss value printed in the log is the current batch, and the metric is the average value of previous step.
# step 157/157 [==============================] - loss: 1.5432 - acc: 0.8374 - 6ms/step
# Eval samples: 10000
# Epoch 2/2
# step 938/938 [==============================] - loss: 1.6056 - acc: 0.8479 - 6ms/step
# save checkpoint at /home/aistudio/multilayer_perceptron/1
# Eval begin...
# The loss value printed in the log is the current batch, and the metric is the average value of previous step.
# step 157/157 [==============================] - loss: 1.5237 - acc: 0.8601 - 6ms/step
# Eval samples: 10000
# save checkpoint at /home/aistudio/multilayer_perceptron/final

# %% [markdown]
#  #### **Step3.模型训练及评估**

# %%
#获取测试集的第一个图片
test_data0, test_label_0 = test_dataset[0][0],test_dataset[0][1]
test_data0 = test_data0.reshape([28,28])
plt.figure(figsize=(2,2))
#展示测试集中的第一个图片
print(plt.imshow(test_data0, cmap=plt.cm.binary))
print('test_data0 的标签为: ' + str(test_label_0))
#模型预测
result = model.predict(test_dataset, batch_size=1)
#打印模型预测的结果
print('test_data0 预测的数值为：%d' % np.argsort(result[0][0])[0][-1])
# Out:
# AxesImage(25,22;155x154)
# test_data0 的标签为: [7]
# Predict begin...
# step 10000/10000 [==============================] - 1ms/step
# Predict samples: 10000
# test_data0 预测的数值为：7

# %% [markdown]
# 以上部分仅为教程, 如果运行，那么可以在运行完之后删除multilayer_perceptron文件夹

# %% [markdown]
# ## 2  实验介绍
# 下面是本次实验要完成的任务。

# %% [markdown]
# ### 2.1 任务介绍：动物识别
#
# 完成动物分类任务，将根据任务完成的情况给分。\
# 助教已经构建好了一个简单的卷积神经网络和训练流程，这是代码中已经实现的部分，你可以在这基础上进行改进。\

# %% [markdown]
# 以下是对于改进的一些提示：
#
# 1.采用数据增强，对输入图片进行裁剪或者旋转等来提高性能。\
# \
# 2.改变网络结构，比如增加卷积层数，或使用vgg等复杂网络的结构。\
# (注意：不要采用任何的预训练模型，并且复杂的网络有过拟合的风险。当网络结构变化时，超参有可能需要重新调整)\
# \
# 3.可自由发挥，提示 : 引入半监督（伪标签）、vision transformer(VIT)等。
#
# 数据集work/data/animal1/semi/目录下是无标签的数据，可利用其产生伪标签从而完成自监督。\
# 半监督参考资料：\
# https://www.bilibili.com/video/BV1Ht411g7Ef?p=23 \
# https://speech.ee.ntu.edu.tw/~tlkagk/courses/ML_2016/Lecture/semi%20(v3).pdf \
# vision transformer资料：\
# https://aistudio.baidu.com/aistudio/projectdetail/1469534 \
# https://zhuanlan.zhihu.com/p/370979971 \
# 鼓励同学们自由发挥，助教给分会更多考虑代码逻辑和完整性。

# %% [markdown]
# ### 2.2 实验介绍：
# 给出的基础代码中实现了对于输入的图片采用卷积神经网络提取特征，再经过全连接后实现图片分类。如下图所示。
# ![](cnn.png)

# %% [markdown]
# ### 2.3  实验要求
# 机器学习一般可以概括为：从数据出发，选择某种模型，通过优化算法更新模型的参数值，使任务的指标表现变好（学习目标），最终学习到“好”的模型，并运用模型对数据做预测以完成任务。由此可见，机器学习方法有四个要素：数据、模型、学习目标、优化算法。本次实验要求熟悉深度学习的一般过程，可搭建简单的神经网络，对数据进行增强以提升分类效果。

# %% [markdown]
# ### 2.4 实验环境
# 飞桨平台基于paddle2.0.2，Python=3.7 \
# 提供的本地代码基于paddle2.6.2，Python=3.8

# %% [markdown]
# ## 3 实验内容

# %% [markdown]
# ### 3.1 准备数据集
# 训练前需要先解压数据文件，并删除一些.zip文件。如果提示文件夹不存在，则建立相应目录再执行命令。
# * 训练集
# * 验证集
# * 公开测试集
# * 私有测试集（无标注）
# * semi数据集（用于半监督，无标注）
#
#
# 对于训练集、验证集和测试集，图片所属于的文件夹就是图像的标签。\
# 你可以自行使用验证集和公开测试集来检验自己模型的效果，助教保留了私有测试集的标注来评估模型。你的模型需要在私有测试集上进行预测，并将预测结果输出到csv文件中，我们将根据预测结果对提交的模型效果进行评分。

# %%
#如果提示文件夹不存在，则在work下新建work/data/animal后再解压
import os
if not os.path.exists('work/data/animal'):
    os.makedirs('work/data/animal')
    # !unzip data/data324341/animal.zip -d work/data/animal/
# Out:
#   inflating: work/data/animal/val/1/sheep_10090.jpg
#   inflating: work/data/animal/val/1/sheep_10091.jpg
#   inflating: work/data/animal/val/1/sheep_10092.jpg
#   inflating: work/data/animal/val/1/sheep_10093.jpg
#   inflating: work/data/animal/val/1/sheep_10094.jpg
#   inflating: work/data/animal/val/1/sheep_10095.jpg
#   inflating: work/data/animal/val/1/sheep_10096.jpg
#   inflating: work/data/animal/val/1/sheep_10097.jpg
#   inflating: work/data/animal/val/1/sheep_10098.jpg
#   inflating: work/data/animal/val/1/sheep_10099.jpg
#   inflating: work/data/animal/val/1/sheep_10100.jpg
#   inflating: work/data/animal/val/1/sheep_10101.jpg
#   inflating: work/data/animal/val/1/sheep_10102.jpg
#   inflating: work/data/animal/val/1/sheep_10103.jpg
#   inflating: work/data/animal/val/1/sheep_10104.jpg
#   inflating: work/data/animal/val/1/sheep_10105.jpg
#   inflating: work/data/animal/val/1/sheep_10106.jpg
#   inflating: work/data/animal/val/1/sheep_10107.jpg
#   inflating: work/data/animal/val/1/sheep_10108.jpg
#   inflating: work/data/animal/val/1/sheep_10109.jpg
#   inflating: work/data/animal/val/1/sheep_10110.jpg
#   inflating: work/data/animal/val/1/sheep_10111.jpg
#   inflating: work/data/animal/val/1/sheep_10112.jpg
#   inflating: work/data/animal/val/1/sheep_10113.jpg
#   inflating: work/data/animal/val/1/sheep_10114.jpg
#   inflating: work/data/animal/val/1/sheep_10115.jpg
#   inflating: work/data/animal/val/1/sheep_10116.jpg
#   inflating: work/data/animal/val/1/sheep_10117.jpg
#   inflating: work/data/animal/val/1/sheep_10118.jpg
#   inflating: work/data/animal/val/1/sheep_10119.jpg
#   inflating: work/data/animal/val/1/sheep_10120.jpg
#   inflating: work/data/animal/val/1/sheep_10121.jpg
#   inflating: work/data/animal/val/1/sheep_10122.jpg
#   inflating: work/data/animal/val/1/sheep_10123.jpg
#   inflating: work/data/animal/val/1/sheep_10124.jpg
#   inflating: work/data/animal/val/1/sheep_10125.jpg
#   inflating: work/data/animal/val/1/sheep_10126.jpg
#   inflating: work/data/animal/val/1/sheep_10127.jpg
#   inflating: work/data/animal/val/1/sheep_10128.jpg
#   inflating: work/data/animal/val/1/sheep_10129.jpg
#   inflating: work/data/animal/val/1/sheep_10130.jpg
#   inflating: work/data/animal/val/1/sheep_10131.jpg
#   inflating: work/data/animal/val/1/sheep_10132.jpg
#   inflating: work/data/animal/val/1/sheep_10133.jpg
#   inflating: work/data/animal/val/1/sheep_10134.jpg
#   inflating: work/data/animal/val/1/sheep_10135.jpg
#   inflating: work/data/animal/val/1/sheep_10136.jpg
#   inflating: work/data/animal/val/1/sheep_10137.jpg
#   inflating: work/data/animal/val/1/sheep_10138.jpg
#   inflating: work/data/animal/val/1/sheep_10139.jpg
#   inflating: work/data/animal/val/1/sheep_10140.jpg
#   inflating: work/data/animal/val/1/sheep_10141.jpg
#   inflating: work/data/animal/val/1/sheep_10142.jpg
#    creating: work/data/animal/val/2/
#   inflating: work/data/animal/val/2/deer_10001.jpg
#   inflating: work/data/animal/val/2/deer_10002.jpg
#   inflating: work/data/animal/val/2/deer_10003.jpg
#   inflating: work/data/animal/val/2/deer_10004.jpg
#   inflating: work/data/animal/val/2/deer_10005.jpg
#   inflating: work/data/animal/val/2/deer_10006.jpg
#   inflating: work/data/animal/val/2/deer_10007.jpg
#   inflating: work/data/animal/val/2/deer_10008.jpg
#   inflating: work/data/animal/val/2/deer_10009.jpg
#   inflating: work/data/animal/val/2/deer_10010.jpg
#   inflating: work/data/animal/val/2/deer_10011.jpg
#   inflating: work/data/animal/val/2/deer_10012.jpg
#   inflating: work/data/animal/val/2/deer_10013.jpg
#   inflating: work/data/animal/val/2/deer_10014.jpg
#   inflating: work/data/animal/val/2/deer_10015.jpg
#   inflating: work/data/animal/val/2/deer_10016.jpg
#   inflating: work/data/animal/val/2/deer_10017.jpg
#   inflating: work/data/animal/val/2/deer_10018.jpg
#   inflating: work/data/animal/val/2/deer_10019.jpg
#   inflating: work/data/animal/val/2/deer_10020.jpg
#   inflating: work/data/animal/val/2/deer_10021.jpg
#   inflating: work/data/animal/val/2/deer_10022.jpg
#   inflating: work/data/animal/val/2/deer_10023.jpg
#   inflating: work/data/animal/val/2/deer_10024.jpg
#   inflating: work/data/animal/val/2/deer_10025.jpg
#   inflating: work/data/animal/val/2/deer_10026.jpg
#   inflating: work/data/animal/val/2/deer_10027.jpg
#   inflating: work/data/animal/val/2/deer_10028.jpg
#   inflating: work/data/animal/val/2/deer_10029.jpg
#   inflating: work/data/animal/val/2/deer_10030.jpg
#   inflating: work/data/animal/val/2/deer_10031.jpg
#   inflating: work/data/animal/val/2/deer_10032.jpg
#   inflating: work/data/animal/val/2/deer_10033.jpg
#   inflating: work/data/animal/val/2/deer_10034.jpg
#   inflating: work/data/animal/val/2/deer_10035.jpg
#   inflating: work/data/animal/val/2/deer_10036.jpg
#   inflating: work/data/animal/val/2/deer_10037.jpg
#   inflating: work/data/animal/val/2/deer_10038.jpg
#   inflating: work/data/animal/val/2/deer_10039.jpg
#   inflating: work/data/animal/val/2/deer_10040.jpg
#   inflating: work/data/animal/val/2/deer_10041.jpg
#   inflating: work/data/animal/val/2/deer_10042.jpg
#   inflating: work/data/animal/val/2/deer_10043.jpg
#   inflating: work/data/animal/val/2/deer_10044.jpg
#   inflating: work/data/animal/val/2/deer_10045.jpg
#   inflating: work/data/animal/val/2/deer_10046.jpg
#   inflating: work/data/animal/val/2/deer_10047.jpg
#   inflating: work/data/animal/val/2/deer_10048.jpg
#   inflating: work/data/animal/val/2/deer_10049.jpg
#   inflating: work/data/animal/val/2/deer_10050.jpg
#   inflating: work/data/animal/val/2/deer_10051.jpg
#   inflating: work/data/animal/val/2/deer_10052.jpg
#   inflating: work/data/animal/val/2/deer_10053.jpg
#   inflating: work/data/animal/val/2/deer_10054.jpg
#   inflating: work/data/animal/val/2/deer_10055.jpg
#   inflating: work/data/animal/val/2/deer_10056.jpg
#   inflating: work/data/animal/val/2/deer_10057.jpg
#   inflating: work/data/animal/val/2/deer_10058.jpg
#   inflating: work/data/animal/val/2/deer_10059.jpg
#   inflating: work/data/animal/val/2/deer_10060.jpg
#   inflating: work/data/animal/val/2/deer_10061.jpg
#   inflating: work/data/animal/val/2/deer_10062.jpg
#   inflating: work/data/animal/val/2/deer_10063.jpg
#   inflating: work/data/animal/val/2/deer_10064.jpg
#   inflating: work/data/animal/val/2/deer_10065.jpg
#   inflating: work/data/animal/val/2/deer_10066.jpg
#   inflating: work/data/animal/val/2/deer_10067.jpg
#   inflating: work/data/animal/val/2/deer_10068.jpg
#   inflating: work/data/animal/val/2/deer_10069.jpg
#   inflating: work/data/animal/val/2/deer_10070.jpg
#   inflating: work/data/animal/val/2/deer_10071.jpg
#   inflating: work/data/animal/val/2/deer_10072.jpg
#   inflating: work/data/animal/val/2/deer_10073.jpg
#   inflating: work/data/animal/val/2/deer_10074.jpg
#   inflating: work/data/animal/val/2/deer_10075.jpg
#   inflating: work/data/animal/val/2/deer_10076.jpg
#   inflating: work/data/animal/val/2/deer_10077.jpg
#   inflating: work/data/animal/val/2/deer_10078.jpg
#   inflating: work/data/animal/val/2/deer_10079.jpg
#   inflating: work/data/animal/val/2/deer_10080.jpg
#   inflating: work/data/animal/val/2/deer_10081.jpg
#   inflating: work/data/animal/val/2/deer_10082.jpg
#   inflating: work/data/animal/val/2/deer_10083.jpg
#   inflating: work/data/animal/val/2/deer_10084.jpg
#   inflating: work/data/animal/val/2/deer_10085.jpg
#   inflating: work/data/animal/val/2/deer_10086.jpg
#   inflating: work/data/animal/val/2/deer_10087.jpg
#   inflating: work/data/animal/val/2/deer_10088.jpg
#   inflating: work/data/animal/val/2/deer_10089.jpg
#   inflating: work/data/animal/val/2/deer_10090.jpg
#   inflating: work/data/animal/val/2/deer_10091.jpg
#   inflating: work/data/animal/val/2/deer_10092.jpg
#   inflating: work/data/animal/val/2/deer_10093.jpg
#   inflating: work/data/animal/val/2/deer_10094.jpg
#   inflating: work/data/animal/val/2/deer_10095.jpg
#   inflating: work/data/animal/val/2/deer_10096.jpg
#   inflating: work/data/animal/val/2/deer_10097.jpg
#   inflating: work/data/animal/val/2/deer_10098.jpg
#   inflating: work/data/animal/val/2/deer_10099.jpg
#   inflating: work/data/animal/val/2/deer_10100.jpg
#   inflating: work/data/animal/val/2/deer_10101.jpg
#   inflating: work/data/animal/val/2/deer_10102.jpg
#   inflating: work/data/animal/val/2/deer_10103.jpg
#   inflating: work/data/animal/val/2/deer_10104.jpg
#   inflating: work/data/animal/val/2/deer_10105.jpg
#   inflating: work/data/animal/val/2/deer_10106.jpg
#   inflating: work/data/animal/val/2/deer_10107.jpg
#   inflating: work/data/animal/val/2/deer_10108.jpg
#   inflating: work/data/animal/val/2/deer_10109.jpg
#   inflating: work/data/animal/val/2/deer_10110.jpg
#   inflating: work/data/animal/val/2/deer_10111.jpg
#   inflating: work/data/animal/val/2/deer_10112.jpg
#   inflating: work/data/animal/val/2/deer_10113.jpg
#   inflating: work/data/animal/val/2/deer_10114.jpg
#   inflating: work/data/animal/val/2/deer_10115.jpg
#   inflating: work/data/animal/val/2/deer_10116.jpg
#   inflating: work/data/animal/val/2/deer_10117.jpg
#   inflating: work/data/animal/val/2/deer_10118.jpg
#   inflating: work/data/animal/val/2/deer_10119.jpg
#   inflating: work/data/animal/val/2/deer_10120.jpg
#   inflating: work/data/animal/val/2/deer_10121.jpg
#   inflating: work/data/animal/val/2/deer_10122.jpg
#   inflating: work/data/animal/val/2/deer_10123.jpg
#   inflating: work/data/animal/val/2/deer_10124.jpg
#   inflating: work/data/animal/val/2/deer_10125.jpg
#   inflating: work/data/animal/val/2/deer_10126.jpg
#   inflating: work/data/animal/val/2/deer_10127.jpg
#   inflating: work/data/animal/val/2/deer_10128.jpg
#   inflating: work/data/animal/val/2/deer_10129.jpg
#   inflating: work/data/animal/val/2/deer_10130.jpg
#   inflating: work/data/animal/val/2/deer_10131.jpg
#   inflating: work/data/animal/val/2/deer_10132.jpg
#   inflating: work/data/animal/val/2/deer_10133.jpg
#   inflating: work/data/animal/val/2/deer_10134.jpg
#    creating: work/data/animal/val/3/
#   inflating: work/data/animal/val/3/cow_10001.jpg
#   inflating: work/data/animal/val/3/cow_10002.jpg
#   inflating: work/data/animal/val/3/cow_10003.jpg
#   inflating: work/data/animal/val/3/cow_10004.jpg
#   inflating: work/data/animal/val/3/cow_10005.jpg
#   inflating: work/data/animal/val/3/cow_10006.jpg
#   inflating: work/data/animal/val/3/cow_10007.jpg
#   inflating: work/data/animal/val/3/cow_10008.jpg
#   inflating: work/data/animal/val/3/cow_10009.jpg
#   inflating: work/data/animal/val/3/cow_10010.jpg
#   inflating: work/data/animal/val/3/cow_10011.jpg
#   inflating: work/data/animal/val/3/cow_10012.jpg
#   inflating: work/data/animal/val/3/cow_10013.jpg
#   inflating: work/data/animal/val/3/cow_10014.jpg
#   inflating: work/data/animal/val/3/cow_10015.jpg
#   inflating: work/data/animal/val/3/cow_10016.jpg
#   inflating: work/data/animal/val/3/cow_10017.jpg
#   inflating: work/data/animal/val/3/cow_10018.jpg
#   inflating: work/data/animal/val/3/cow_10019.jpg
#   inflating: work/data/animal/val/3/cow_10020.jpg
#   inflating: work/data/animal/val/3/cow_10021.jpg
#   inflating: work/data/animal/val/3/cow_10022.jpg
#   inflating: work/data/animal/val/3/cow_10023.jpg
#   inflating: work/data/animal/val/3/cow_10024.jpg
#   inflating: work/data/animal/val/3/cow_10025.jpg
#   inflating: work/data/animal/val/3/cow_10026.jpg
#   inflating: work/data/animal/val/3/cow_10027.jpg
#   inflating: work/data/animal/val/3/cow_10028.jpg
#   inflating: work/data/animal/val/3/cow_10029.jpg
#   inflating: work/data/animal/val/3/cow_10030.jpg
#   inflating: work/data/animal/val/3/cow_10031.jpg
#   inflating: work/data/animal/val/3/cow_10032.jpg
#   inflating: work/data/animal/val/3/cow_10033.jpg
#   inflating: work/data/animal/val/3/cow_10034.jpg
#   inflating: work/data/animal/val/3/cow_10035.jpg
#   inflating: work/data/animal/val/3/cow_10036.jpg
#   inflating: work/data/animal/val/3/cow_10037.jpg
#   inflating: work/data/animal/val/3/cow_10038.jpg
#   inflating: work/data/animal/val/3/cow_10039.jpg
#   inflating: work/data/animal/val/3/cow_10040.jpg
#   inflating: work/data/animal/val/3/cow_10041.jpg
#   inflating: work/data/animal/val/3/cow_10042.jpg
#   inflating: work/data/animal/val/3/cow_10043.jpg
#   inflating: work/data/animal/val/3/cow_10044.jpg
#   inflating: work/data/animal/val/3/cow_10045.jpg
#   inflating: work/data/animal/val/3/cow_10046.jpg
#   inflating: work/data/animal/val/3/cow_10047.jpg
#   inflating: work/data/animal/val/3/cow_10048.jpg
#   inflating: work/data/animal/val/3/cow_10049.jpg
#   inflating: work/data/animal/val/3/cow_10050.jpg
#   inflating: work/data/animal/val/3/cow_10051.jpg
#   inflating: work/data/animal/val/3/cow_10052.jpg
#   inflating: work/data/animal/val/3/cow_10053.jpg
#   inflating: work/data/animal/val/3/cow_10054.jpg
#   inflating: work/data/animal/val/3/cow_10055.jpg
#   inflating: work/data/animal/val/3/cow_10056.jpg
#   inflating: work/data/animal/val/3/cow_10057.jpg
#   inflating: work/data/animal/val/3/cow_10058.jpg
#   inflating: work/data/animal/val/3/cow_10059.jpg
#   inflating: work/data/animal/val/3/cow_10060.jpg
#   inflating: work/data/animal/val/3/cow_10061.jpg
#   inflating: work/data/animal/val/3/cow_10062.jpg
#   inflating: work/data/animal/val/3/cow_10063.jpg
#   inflating: work/data/animal/val/3/cow_10064.jpg
#   inflating: work/data/animal/val/3/cow_10065.jpg
#   inflating: work/data/animal/val/3/cow_10066.jpg
#   inflating: work/data/animal/val/3/cow_10067.jpg
#   inflating: work/data/animal/val/3/cow_10068.jpg
#   inflating: work/data/animal/val/3/cow_10069.jpg
#   inflating: work/data/animal/val/3/cow_10070.jpg
#   inflating: work/data/animal/val/3/cow_10071.jpg
#   inflating: work/data/animal/val/3/cow_10072.jpg
#   inflating: work/data/animal/val/3/cow_10073.jpg
#   inflating: work/data/animal/val/3/cow_10074.jpg
#   inflating: work/data/animal/val/3/cow_10075.jpg
#   inflating: work/data/animal/val/3/cow_10076.jpg
#   inflating: work/data/animal/val/3/cow_10077.jpg
#   inflating: work/data/animal/val/3/cow_10078.jpg
#   inflating: work/data/animal/val/3/cow_10079.jpg
#   inflating: work/data/animal/val/3/cow_10080.jpg
#   inflating: work/data/animal/val/3/cow_10081.jpg
#   inflating: work/data/animal/val/3/cow_10082.jpg
#   inflating: work/data/animal/val/3/cow_10083.jpg
#   inflating: work/data/animal/val/3/cow_10084.jpg
#   inflating: work/data/animal/val/3/cow_10085.jpg
#   inflating: work/data/animal/val/3/cow_10086.jpg
#   inflating: work/data/animal/val/3/cow_10087.jpg
#   inflating: work/data/animal/val/3/cow_10088.jpg
#   inflating: work/data/animal/val/3/cow_10089.jpg
#   inflating: work/data/animal/val/3/cow_10090.jpg
#   inflating: work/data/animal/val/3/cow_10091.jpg
#   inflating: work/data/animal/val/3/cow_10092.jpg
#   inflating: work/data/animal/val/3/cow_10093.jpg
#   inflating: work/data/animal/val/3/cow_10094.jpg
#   inflating: work/data/animal/val/3/cow_10095.jpg
#   inflating: work/data/animal/val/3/cow_10096.jpg
#   inflating: work/data/animal/val/3/cow_10097.jpg
#   inflating: work/data/animal/val/3/cow_10098.jpg
#   inflating: work/data/animal/val/3/cow_10099.jpg
#   inflating: work/data/animal/val/3/cow_10100.jpg
#   inflating: work/data/animal/val/3/cow_10101.jpg
#   inflating: work/data/animal/val/3/cow_10102.jpg
#   inflating: work/data/animal/val/3/cow_10103.jpg
#   inflating: work/data/animal/val/3/cow_10104.jpg
#   inflating: work/data/animal/val/3/cow_10105.jpg
#   inflating: work/data/animal/val/3/cow_10106.jpg
#   inflating: work/data/animal/val/3/cow_10107.jpg
#   inflating: work/data/animal/val/3/cow_10108.jpg
#   inflating: work/data/animal/val/3/cow_10109.jpg
#   inflating: work/data/animal/val/3/cow_10110.jpg
#   inflating: work/data/animal/val/3/cow_10111.jpg
#   inflating: work/data/animal/val/3/cow_10112.jpg
#   inflating: work/data/animal/val/3/cow_10113.jpg
#   inflating: work/data/animal/val/3/cow_10114.jpg
#   inflating: work/data/animal/val/3/cow_10115.jpg
#   inflating: work/data/animal/val/3/cow_10116.jpg
#   inflating: work/data/animal/val/3/cow_10117.jpg
#   inflating: work/data/animal/val/3/cow_10118.jpg
#   inflating: work/data/animal/val/3/cow_10119.jpg
#   inflating: work/data/animal/val/3/cow_10120.jpg
#   inflating: work/data/animal/val/3/cow_10121.jpg
#   inflating: work/data/animal/val/3/cow_10122.jpg
#   inflating: work/data/animal/val/3/cow_10123.jpg
#   inflating: work/data/animal/val/3/cow_10124.jpg
#   inflating: work/data/animal/val/3/cow_10125.jpg
#   inflating: work/data/animal/val/3/cow_10126.jpg
#   inflating: work/data/animal/val/3/cow_10127.jpg
#   inflating: work/data/animal/val/3/cow_10128.jpg
#   inflating: work/data/animal/val/3/cow_10129.jpg
#   inflating: work/data/animal/val/3/cow_10130.jpg
#   inflating: work/data/animal/val/3/cow_10131.jpg
#   inflating: work/data/animal/val/3/cow_10132.jpg
#   inflating: work/data/animal/val/3/cow_10133.jpg
#    creating: work/data/animal/val/4/
#   inflating: work/data/animal/val/4/giraffe_10001.jpg
#   inflating: work/data/animal/val/4/giraffe_10002.jpg
#   inflating: work/data/animal/val/4/giraffe_10003.jpg
#   inflating: work/data/animal/val/4/giraffe_10004.jpg
#   inflating: work/data/animal/val/4/giraffe_10005.jpg
#   inflating: work/data/animal/val/4/giraffe_10006.jpg
#   inflating: work/data/animal/val/4/giraffe_10007.jpg
#   inflating: work/data/animal/val/4/giraffe_10008.jpg
#   inflating: work/data/animal/val/4/giraffe_10009.jpg
#   inflating: work/data/animal/val/4/giraffe_10010.jpg
#   inflating: work/data/animal/val/4/giraffe_10011.jpg
#   inflating: work/data/animal/val/4/giraffe_10012.jpg
#   inflating: work/data/animal/val/4/giraffe_10013.jpg
#   inflating: work/data/animal/val/4/giraffe_10014.jpg
#   inflating: work/data/animal/val/4/giraffe_10015.jpg
#   inflating: work/data/animal/val/4/giraffe_10016.jpg
#   inflating: work/data/animal/val/4/giraffe_10017.jpg
#   inflating: work/data/animal/val/4/giraffe_10018.jpg
#   inflating: work/data/animal/val/4/giraffe_10019.jpg
#   inflating: work/data/animal/val/4/giraffe_10020.jpg
#   inflating: work/data/animal/val/4/giraffe_10021.jpg
#   inflating: work/data/animal/val/4/giraffe_10022.jpg
#   inflating: work/data/animal/val/4/giraffe_10023.jpg
#   inflating: work/data/animal/val/4/giraffe_10024.jpg
#   inflating: work/data/animal/val/4/giraffe_10025.jpg
#   inflating: work/data/animal/val/4/giraffe_10026.jpg
#   inflating: work/data/animal/val/4/giraffe_10027.jpg
#   inflating: work/data/animal/val/4/giraffe_10028.jpg
#   inflating: work/data/animal/val/4/giraffe_10029.jpg
#   inflating: work/data/animal/val/4/giraffe_10030.jpg
#   inflating: work/data/animal/val/4/giraffe_10031.jpg
#   inflating: work/data/animal/val/4/giraffe_10032.jpg
#   inflating: work/data/animal/val/4/giraffe_10033.jpg
#   inflating: work/data/animal/val/4/giraffe_10034.jpg
#   inflating: work/data/animal/val/4/giraffe_10035.jpg
#   inflating: work/data/animal/val/4/giraffe_10036.jpg
#   inflating: work/data/animal/val/4/giraffe_10037.jpg
#   inflating: work/data/animal/val/4/giraffe_10038.jpg
#   inflating: work/data/animal/val/4/giraffe_10039.jpg
#   inflating: work/data/animal/val/4/giraffe_10040.jpg
#   inflating: work/data/animal/val/4/giraffe_10041.jpg
#   inflating: work/data/animal/val/4/giraffe_10042.jpg
#   inflating: work/data/animal/val/4/giraffe_10043.jpg
#   inflating: work/data/animal/val/4/giraffe_10044.jpg
#   inflating: work/data/animal/val/4/giraffe_10045.jpg
#   inflating: work/data/animal/val/4/giraffe_10046.jpg
#   inflating: work/data/animal/val/4/giraffe_10047.jpg
#   inflating: work/data/animal/val/4/giraffe_10048.jpg
#   inflating: work/data/animal/val/4/giraffe_10049.jpg
#   inflating: work/data/animal/val/4/giraffe_10050.jpg
#   inflating: work/data/animal/val/4/giraffe_10051.jpg
#   inflating: work/data/animal/val/4/giraffe_10052.jpg
#   inflating: work/data/animal/val/4/giraffe_10053.jpg
#   inflating: work/data/animal/val/4/giraffe_10054.jpg
#   inflating: work/data/animal/val/4/giraffe_10055.jpg
#   inflating: work/data/animal/val/4/giraffe_10056.jpg
#   inflating: work/data/animal/val/4/giraffe_10057.jpg
#   inflating: work/data/animal/val/4/giraffe_10058.jpg
#   inflating: work/data/animal/val/4/giraffe_10059.jpg
#   inflating: work/data/animal/val/4/giraffe_10060.jpg
#   inflating: work/data/animal/val/4/giraffe_10061.jpg
#   inflating: work/data/animal/val/4/giraffe_10062.jpg
#   inflating: work/data/animal/val/4/giraffe_10063.jpg
#   inflating: work/data/animal/val/4/giraffe_10064.jpg
#   inflating: work/data/animal/val/4/giraffe_10065.jpg
#   inflating: work/data/animal/val/4/giraffe_10066.jpg
#   inflating: work/data/animal/val/4/giraffe_10067.jpg
#   inflating: work/data/animal/val/4/giraffe_10068.jpg
#   inflating: work/data/animal/val/4/giraffe_10069.jpg
#   inflating: work/data/animal/val/4/giraffe_10070.jpg
#   inflating: work/data/animal/val/4/giraffe_10071.jpg
#   inflating: work/data/animal/val/4/giraffe_10072.jpg
#   inflating: work/data/animal/val/4/giraffe_10073.jpg
#   inflating: work/data/animal/val/4/giraffe_10074.jpg
#   inflating: work/data/animal/val/4/giraffe_10075.jpg
#   inflating: work/data/animal/val/4/giraffe_10076.jpg
#   inflating: work/data/animal/val/4/giraffe_10077.jpg
#   inflating: work/data/animal/val/4/giraffe_10078.jpg
#   inflating: work/data/animal/val/4/giraffe_10079.jpg
#   inflating: work/data/animal/val/4/giraffe_10080.jpg
#   inflating: work/data/animal/val/4/giraffe_10081.jpg
#   inflating: work/data/animal/val/4/giraffe_10082.jpg
#   inflating: work/data/animal/val/4/giraffe_10083.jpg
#   inflating: work/data/animal/val/4/giraffe_10084.jpg
#   inflating: work/data/animal/val/4/giraffe_10085.jpg
#   inflating: work/data/animal/val/4/giraffe_10086.jpg
#   inflating: work/data/animal/val/4/giraffe_10087.jpg
#   inflating: work/data/animal/val/4/giraffe_10088.jpg
#   inflating: work/data/animal/val/4/giraffe_10089.jpg
#   inflating: work/data/animal/val/4/giraffe_10090.jpg
#   inflating: work/data/animal/val/4/giraffe_10091.jpg
#   inflating: work/data/animal/val/4/giraffe_10092.jpg
#   inflating: work/data/animal/val/4/giraffe_10093.jpg
#   inflating: work/data/animal/val/4/giraffe_10094.jpg
#   inflating: work/data/animal/val/4/giraffe_10095.jpg
#   inflating: work/data/animal/val/4/giraffe_10096.jpg
#   inflating: work/data/animal/val/4/giraffe_10097.jpg
#   inflating: work/data/animal/val/4/giraffe_10098.jpg
#   inflating: work/data/animal/val/4/giraffe_10099.jpg
#   inflating: work/data/animal/val/4/giraffe_10100.jpg
#   inflating: work/data/animal/val/4/giraffe_10101.jpg
#   inflating: work/data/animal/val/4/giraffe_10102.jpg
#   inflating: work/data/animal/val/4/giraffe_10103.jpg
#   inflating: work/data/animal/val/4/giraffe_10104.jpg
#   inflating: work/data/animal/val/4/giraffe_10105.jpg
#   inflating: work/data/animal/val/4/giraffe_10106.jpg
#   inflating: work/data/animal/val/4/giraffe_10107.jpg
#   inflating: work/data/animal/val/4/giraffe_10108.jpg
#   inflating: work/data/animal/val/4/giraffe_10109.jpg
#   inflating: work/data/animal/val/4/giraffe_10110.jpg
#   inflating: work/data/animal/val/4/giraffe_10111.jpg
#   inflating: work/data/animal/val/4/giraffe_10112.jpg
#   inflating: work/data/animal/val/4/giraffe_10113.jpg
#   inflating: work/data/animal/val/4/giraffe_10114.jpg
#   inflating: work/data/animal/val/4/giraffe_10115.jpg
#   inflating: work/data/animal/val/4/giraffe_10116.jpg
#   inflating: work/data/animal/val/4/giraffe_10117.jpg
#   inflating: work/data/animal/val/4/giraffe_10118.jpg
#   inflating: work/data/animal/val/4/giraffe_10119.jpg
#   inflating: work/data/animal/val/4/giraffe_10120.jpg
#    creating: work/data/animal/val/5/
#   inflating: work/data/animal/val/5/squirrel_10001.jpg
#   inflating: work/data/animal/val/5/squirrel_10002.jpg
#   inflating: work/data/animal/val/5/squirrel_10003.jpg
#   inflating: work/data/animal/val/5/squirrel_10004.jpg
#   inflating: work/data/animal/val/5/squirrel_10005.jpg
#   inflating: work/data/animal/val/5/squirrel_10006.jpg
#   inflating: work/data/animal/val/5/squirrel_10007.jpg
#   inflating: work/data/animal/val/5/squirrel_10008.jpg
#   inflating: work/data/animal/val/5/squirrel_10009.jpg
#   inflating: work/data/animal/val/5/squirrel_10010.jpg
#   inflating: work/data/animal/val/5/squirrel_10011.jpg
#   inflating: work/data/animal/val/5/squirrel_10012.jpg
#   inflating: work/data/animal/val/5/squirrel_10013.jpg
#   inflating: work/data/animal/val/5/squirrel_10014.jpg
#   inflating: work/data/animal/val/5/squirrel_10015.jpg
#   inflating: work/data/animal/val/5/squirrel_10016.jpg
#   inflating: work/data/animal/val/5/squirrel_10017.jpg
#   inflating: work/data/animal/val/5/squirrel_10018.jpg
#   inflating: work/data/animal/val/5/squirrel_10019.jpg
#   inflating: work/data/animal/val/5/squirrel_10020.jpg
#   inflating: work/data/animal/val/5/squirrel_10021.jpg
#   inflating: work/data/animal/val/5/squirrel_10022.jpg
#   inflating: work/data/animal/val/5/squirrel_10023.jpg
#   inflating: work/data/animal/val/5/squirrel_10024.jpg
#   inflating: work/data/animal/val/5/squirrel_10025.jpg
#   inflating: work/data/animal/val/5/squirrel_10026.jpg
#   inflating: work/data/animal/val/5/squirrel_10027.jpg
#   inflating: work/data/animal/val/5/squirrel_10028.jpg
#   inflating: work/data/animal/val/5/squirrel_10029.jpg
#   inflating: work/data/animal/val/5/squirrel_10030.jpg
#   inflating: work/data/animal/val/5/squirrel_10031.jpg
#   inflating: work/data/animal/val/5/squirrel_10032.jpg
#   inflating: work/data/animal/val/5/squirrel_10033.jpg
#   inflating: work/data/animal/val/5/squirrel_10034.jpg
#   inflating: work/data/animal/val/5/squirrel_10035.jpg
#   inflating: work/data/animal/val/5/squirrel_10036.jpg
#   inflating: work/data/animal/val/5/squirrel_10037.jpg
#   inflating: work/data/animal/val/5/squirrel_10038.jpg
#   inflating: work/data/animal/val/5/squirrel_10039.jpg
#   inflating: work/data/animal/val/5/squirrel_10040.jpg
#   inflating: work/data/animal/val/5/squirrel_10041.jpg
#   inflating: work/data/animal/val/5/squirrel_10042.jpg
#   inflating: work/data/animal/val/5/squirrel_10043.jpg
#   inflating: work/data/animal/val/5/squirrel_10044.jpg
#   inflating: work/data/animal/val/5/squirrel_10045.jpg
#   inflating: work/data/animal/val/5/squirrel_10046.jpg
#   inflating: work/data/animal/val/5/squirrel_10047.jpg
#   inflating: work/data/animal/val/5/squirrel_10048.jpg
#   inflating: work/data/animal/val/5/squirrel_10049.jpg
#   inflating: work/data/animal/val/5/squirrel_10050.jpg
#   inflating: work/data/animal/val/5/squirrel_10051.jpg
#   inflating: work/data/animal/val/5/squirrel_10052.jpg
#   inflating: work/data/animal/val/5/squirrel_10053.jpg
#   inflating: work/data/animal/val/5/squirrel_10054.jpg
#   inflating: work/data/animal/val/5/squirrel_10055.jpg
#   inflating: work/data/animal/val/5/squirrel_10056.jpg
#   inflating: work/data/animal/val/5/squirrel_10057.jpg
#   inflating: work/data/animal/val/5/squirrel_10058.jpg
#   inflating: work/data/animal/val/5/squirrel_10059.jpg
#   inflating: work/data/animal/val/5/squirrel_10060.jpg
#   inflating: work/data/animal/val/5/squirrel_10061.jpg
#   inflating: work/data/animal/val/5/squirrel_10062.jpg
#   inflating: work/data/animal/val/5/squirrel_10063.jpg
#   inflating: work/data/animal/val/5/squirrel_10064.jpg
#   inflating: work/data/animal/val/5/squirrel_10065.jpg
#   inflating: work/data/animal/val/5/squirrel_10066.jpg
#   inflating: work/data/animal/val/5/squirrel_10067.jpg
#   inflating: work/data/animal/val/5/squirrel_10068.jpg
#   inflating: work/data/animal/val/5/squirrel_10069.jpg
#   inflating: work/data/animal/val/5/squirrel_10070.jpg
#   inflating: work/data/animal/val/5/squirrel_10071.jpg
#   inflating: work/data/animal/val/5/squirrel_10072.jpg
#   inflating: work/data/animal/val/5/squirrel_10073.jpg
#   inflating: work/data/animal/val/5/squirrel_10074.jpg
#   inflating: work/data/animal/val/5/squirrel_10075.jpg
#   inflating: work/data/animal/val/5/squirrel_10076.jpg
#   inflating: work/data/animal/val/5/squirrel_10077.jpg
#   inflating: work/data/animal/val/5/squirrel_10078.jpg
#   inflating: work/data/animal/val/5/squirrel_10079.jpg
#   inflating: work/data/animal/val/5/squirrel_10080.jpg
#   inflating: work/data/animal/val/5/squirrel_10081.jpg
#   inflating: work/data/animal/val/5/squirrel_10082.jpg
#   inflating: work/data/animal/val/5/squirrel_10083.jpg
#   inflating: work/data/animal/val/5/squirrel_10084.jpg
#   inflating: work/data/animal/val/5/squirrel_10085.jpg
#   inflating: work/data/animal/val/5/squirrel_10086.jpg
#   inflating: work/data/animal/val/5/squirrel_10087.jpg
#   inflating: work/data/animal/val/5/squirrel_10088.jpg
#   inflating: work/data/animal/val/5/squirrel_10089.jpg
#   inflating: work/data/animal/val/5/squirrel_10090.jpg
#   inflating: work/data/animal/val/5/squirrel_10091.jpg
#   inflating: work/data/animal/val/5/squirrel_10092.jpg
#   inflating: work/data/animal/val/5/squirrel_10093.jpg
#   inflating: work/data/animal/val/5/squirrel_10094.jpg
#   inflating: work/data/animal/val/5/squirrel_10095.jpg
#   inflating: work/data/animal/val/5/squirrel_10096.jpg
#   inflating: work/data/animal/val/5/squirrel_10097.jpg
#   inflating: work/data/animal/val/5/squirrel_10098.jpg
#   inflating: work/data/animal/val/5/squirrel_10099.jpg
#   inflating: work/data/animal/val/5/squirrel_10100.jpg
#   inflating: work/data/animal/val/5/squirrel_10101.jpg
#   inflating: work/data/animal/val/5/squirrel_10102.jpg
#   inflating: work/data/animal/val/5/squirrel_10103.jpg
#   inflating: work/data/animal/val/5/squirrel_10104.jpg
#   inflating: work/data/animal/val/5/squirrel_10105.jpg
#   inflating: work/data/animal/val/5/squirrel_10106.jpg
#   inflating: work/data/animal/val/5/squirrel_10107.jpg
#   inflating: work/data/animal/val/5/squirrel_10108.jpg
#   inflating: work/data/animal/val/5/squirrel_10109.jpg
#   inflating: work/data/animal/val/5/squirrel_10110.jpg
#   inflating: work/data/animal/val/5/squirrel_10111.jpg
#   inflating: work/data/animal/val/5/squirrel_10112.jpg
#   inflating: work/data/animal/val/5/squirrel_10113.jpg
#   inflating: work/data/animal/val/5/squirrel_10114.jpg
#   inflating: work/data/animal/val/5/squirrel_10115.jpg
#   inflating: work/data/animal/val/5/squirrel_10116.jpg
#   inflating: work/data/animal/val/5/squirrel_10117.jpg
#   inflating: work/data/animal/val/5/squirrel_10118.jpg
#   inflating: work/data/animal/val/5/squirrel_10119.jpg
#   inflating: work/data/animal/val/5/squirrel_10120.jpg
#    creating: work/data/animal/val/6/
#   inflating: work/data/animal/val/6/zebra_10001.jpg
#   inflating: work/data/animal/val/6/zebra_10002.jpg
#   inflating: work/data/animal/val/6/zebra_10003.jpg
#   inflating: work/data/animal/val/6/zebra_10004.jpg
#   inflating: work/data/animal/val/6/zebra_10005.jpg
#   inflating: work/data/animal/val/6/zebra_10006.jpg
#   inflating: work/data/animal/val/6/zebra_10007.jpg
#   inflating: work/data/animal/val/6/zebra_10008.jpg
#   inflating: work/data/animal/val/6/zebra_10009.jpg
#   inflating: work/data/animal/val/6/zebra_10010.jpg
#   inflating: work/data/animal/val/6/zebra_10011.jpg
#   inflating: work/data/animal/val/6/zebra_10012.jpg
#   inflating: work/data/animal/val/6/zebra_10013.jpg
#   inflating: work/data/animal/val/6/zebra_10014.jpg
#   inflating: work/data/animal/val/6/zebra_10015.jpg
#   inflating: work/data/animal/val/6/zebra_10016.jpg
#   inflating: work/data/animal/val/6/zebra_10017.jpg
#   inflating: work/data/animal/val/6/zebra_10018.jpg
#   inflating: work/data/animal/val/6/zebra_10019.jpg
#   inflating: work/data/animal/val/6/zebra_10020.jpg
#   inflating: work/data/animal/val/6/zebra_10021.jpg
#   inflating: work/data/animal/val/6/zebra_10022.jpg
#   inflating: work/data/animal/val/6/zebra_10023.jpg
#   inflating: work/data/animal/val/6/zebra_10024.jpg
#   inflating: work/data/animal/val/6/zebra_10025.jpg
#   inflating: work/data/animal/val/6/zebra_10026.jpg
#   inflating: work/data/animal/val/6/zebra_10027.jpg
#   inflating: work/data/animal/val/6/zebra_10028.jpg
#   inflating: work/data/animal/val/6/zebra_10029.jpg
#   inflating: work/data/animal/val/6/zebra_10030.jpg
#   inflating: work/data/animal/val/6/zebra_10031.jpg
#   inflating: work/data/animal/val/6/zebra_10032.jpg
#   inflating: work/data/animal/val/6/zebra_10033.jpg
#   inflating: work/data/animal/val/6/zebra_10034.jpg
#   inflating: work/data/animal/val/6/zebra_10035.jpg
#   inflating: work/data/animal/val/6/zebra_10036.jpg
#   inflating: work/data/animal/val/6/zebra_10037.jpg
#   inflating: work/data/animal/val/6/zebra_10038.jpg
#   inflating: work/data/animal/val/6/zebra_10039.jpg
#   inflating: work/data/animal/val/6/zebra_10040.jpg
#   inflating: work/data/animal/val/6/zebra_10041.jpg
#   inflating: work/data/animal/val/6/zebra_10042.jpg
#   inflating: work/data/animal/val/6/zebra_10043.jpg
#   inflating: work/data/animal/val/6/zebra_10044.jpg
#   inflating: work/data/animal/val/6/zebra_10045.jpg
#   inflating: work/data/animal/val/6/zebra_10046.jpg
#   inflating: work/data/animal/val/6/zebra_10047.jpg
#   inflating: work/data/animal/val/6/zebra_10048.jpg
#   inflating: work/data/animal/val/6/zebra_10049.jpg
#   inflating: work/data/animal/val/6/zebra_10050.jpg
#   inflating: work/data/animal/val/6/zebra_10051.jpg
#   inflating: work/data/animal/val/6/zebra_10052.jpg
#   inflating: work/data/animal/val/6/zebra_10053.jpg
#   inflating: work/data/animal/val/6/zebra_10054.jpg
#   inflating: work/data/animal/val/6/zebra_10055.jpg
#   inflating: work/data/animal/val/6/zebra_10056.jpg
#   inflating: work/data/animal/val/6/zebra_10057.jpg
#   inflating: work/data/animal/val/6/zebra_10058.jpg
#   inflating: work/data/animal/val/6/zebra_10059.jpg
#   inflating: work/data/animal/val/6/zebra_10060.jpg
#   inflating: work/data/animal/val/6/zebra_10061.jpg
#   inflating: work/data/animal/val/6/zebra_10062.jpg
#   inflating: work/data/animal/val/6/zebra_10063.jpg
#   inflating: work/data/animal/val/6/zebra_10064.jpg
#   inflating: work/data/animal/val/6/zebra_10065.jpg
#   inflating: work/data/animal/val/6/zebra_10066.jpg
#   inflating: work/data/animal/val/6/zebra_10067.jpg
#   inflating: work/data/animal/val/6/zebra_10068.jpg
#   inflating: work/data/animal/val/6/zebra_10069.jpg
#   inflating: work/data/animal/val/6/zebra_10070.jpg
#   inflating: work/data/animal/val/6/zebra_10071.jpg
#   inflating: work/data/animal/val/6/zebra_10072.jpg
#   inflating: work/data/animal/val/6/zebra_10073.jpg
#   inflating: work/data/animal/val/6/zebra_10074.jpg
#   inflating: work/data/animal/val/6/zebra_10075.jpg
#   inflating: work/data/animal/val/6/zebra_10076.jpg
#   inflating: work/data/animal/val/6/zebra_10077.jpg
#   inflating: work/data/animal/val/6/zebra_10078.jpg
#   inflating: work/data/animal/val/6/zebra_10079.jpg
#   inflating: work/data/animal/val/6/zebra_10080.jpg
#   inflating: work/data/animal/val/6/zebra_10081.jpg
#   inflating: work/data/animal/val/6/zebra_10082.jpg
#   inflating: work/data/animal/val/6/zebra_10083.jpg
#   inflating: work/data/animal/val/6/zebra_10084.jpg
#   inflating: work/data/animal/val/6/zebra_10085.jpg
#   inflating: work/data/animal/val/6/zebra_10086.jpg
#   inflating: work/data/animal/val/6/zebra_10087.jpg
#   inflating: work/data/animal/val/6/zebra_10088.jpg
#   inflating: work/data/animal/val/6/zebra_10089.jpg
#   inflating: work/data/animal/val/6/zebra_10090.jpg
#   inflating: work/data/animal/val/6/zebra_10091.jpg
#   inflating: work/data/animal/val/6/zebra_10092.jpg
#   inflating: work/data/animal/val/6/zebra_10093.jpg
#   inflating: work/data/animal/val/6/zebra_10094.jpg
#   inflating: work/data/animal/val/6/zebra_10095.jpg
#   inflating: work/data/animal/val/6/zebra_10096.jpg
#   inflating: work/data/animal/val/6/zebra_10097.jpg
#   inflating: work/data/animal/val/6/zebra_10098.jpg
#   inflating: work/data/animal/val/6/zebra_10099.jpg
#   inflating: work/data/animal/val/6/zebra_10100.jpg
#   inflating: work/data/animal/val/6/zebra_10101.jpg
#   inflating: work/data/animal/val/6/zebra_10102.jpg
#   inflating: work/data/animal/val/6/zebra_10103.jpg
#   inflating: work/data/animal/val/6/zebra_10104.jpg
#   inflating: work/data/animal/val/6/zebra_10105.jpg
#   inflating: work/data/animal/val/6/zebra_10106.jpg
#   inflating: work/data/animal/val/6/zebra_10107.jpg
#   inflating: work/data/animal/val/6/zebra_10108.jpg
#   inflating: work/data/animal/val/6/zebra_10109.jpg
#   inflating: work/data/animal/val/6/zebra_10110.jpg
#   inflating: work/data/animal/val/6/zebra_10111.jpg
#   inflating: work/data/animal/val/6/zebra_10112.jpg
#   inflating: work/data/animal/val/6/zebra_10113.jpg
#   inflating: work/data/animal/val/6/zebra_10114.jpg
#   inflating: work/data/animal/val/6/zebra_10115.jpg
#   inflating: work/data/animal/val/6/zebra_10116.jpg
#   inflating: work/data/animal/val/6/zebra_10117.jpg
#    creating: work/data/animal/val/7/
#   inflating: work/data/animal/val/7/rabbit_10001.jpg
#   inflating: work/data/animal/val/7/rabbit_10002.jpg
#   inflating: work/data/animal/val/7/rabbit_10003.jpg
#   inflating: work/data/animal/val/7/rabbit_10004.jpg
#   inflating: work/data/animal/val/7/rabbit_10005.jpg
#   inflating: work/data/animal/val/7/rabbit_10006.jpg
#   inflating: work/data/animal/val/7/rabbit_10007.jpg
#   inflating: work/data/animal/val/7/rabbit_10008.jpg
#   inflating: work/data/animal/val/7/rabbit_10009.jpg
#   inflating: work/data/animal/val/7/rabbit_10010.jpg
#   inflating: work/data/animal/val/7/rabbit_10011.jpg
#   inflating: work/data/animal/val/7/rabbit_10012.jpg
#   inflating: work/data/animal/val/7/rabbit_10013.jpg
#   inflating: work/data/animal/val/7/rabbit_10014.jpg
#   inflating: work/data/animal/val/7/rabbit_10015.jpg
#   inflating: work/data/animal/val/7/rabbit_10016.jpg
#   inflating: work/data/animal/val/7/rabbit_10017.jpg
#   inflating: work/data/animal/val/7/rabbit_10018.jpg
#   inflating: work/data/animal/val/7/rabbit_10019.jpg
#   inflating: work/data/animal/val/7/rabbit_10020.jpg
#   inflating: work/data/animal/val/7/rabbit_10021.jpg
#   inflating: work/data/animal/val/7/rabbit_10022.jpg
#   inflating: work/data/animal/val/7/rabbit_10023.jpg
#   inflating: work/data/animal/val/7/rabbit_10024.jpg
#   inflating: work/data/animal/val/7/rabbit_10025.jpg
#   inflating: work/data/animal/val/7/rabbit_10026.jpg
#   inflating: work/data/animal/val/7/rabbit_10027.jpg
#   inflating: work/data/animal/val/7/rabbit_10028.jpg
#   inflating: work/data/animal/val/7/rabbit_10029.jpg
#   inflating: work/data/animal/val/7/rabbit_10030.jpg
#   inflating: work/data/animal/val/7/rabbit_10031.jpg
#   inflating: work/data/animal/val/7/rabbit_10032.jpg
#   inflating: work/data/animal/val/7/rabbit_10033.jpg
#   inflating: work/data/animal/val/7/rabbit_10034.jpg
#   inflating: work/data/animal/val/7/rabbit_10035.jpg
#   inflating: work/data/animal/val/7/rabbit_10036.jpg
#   inflating: work/data/animal/val/7/rabbit_10037.jpg
#   inflating: work/data/animal/val/7/rabbit_10038.jpg
#   inflating: work/data/animal/val/7/rabbit_10039.jpg
#   inflating: work/data/animal/val/7/rabbit_10040.jpg
#   inflating: work/data/animal/val/7/rabbit_10041.jpg
#   inflating: work/data/animal/val/7/rabbit_10042.jpg
#   inflating: work/data/animal/val/7/rabbit_10043.jpg
#   inflating: work/data/animal/val/7/rabbit_10044.jpg
#   inflating: work/data/animal/val/7/rabbit_10045.jpg
#   inflating: work/data/animal/val/7/rabbit_10046.jpg
#   inflating: work/data/animal/val/7/rabbit_10047.jpg
#   inflating: work/data/animal/val/7/rabbit_10048.jpg
#   inflating: work/data/animal/val/7/rabbit_10049.jpg
#   inflating: work/data/animal/val/7/rabbit_10050.jpg
#   inflating: work/data/animal/val/7/rabbit_10051.jpg
#   inflating: work/data/animal/val/7/rabbit_10052.jpg
#   inflating: work/data/animal/val/7/rabbit_10053.jpg
#   inflating: work/data/animal/val/7/rabbit_10054.jpg
#   inflating: work/data/animal/val/7/rabbit_10055.jpg
#   inflating: work/data/animal/val/7/rabbit_10056.jpg
#   inflating: work/data/animal/val/7/rabbit_10057.jpg
#   inflating: work/data/animal/val/7/rabbit_10058.jpg
#   inflating: work/data/animal/val/7/rabbit_10059.jpg
#   inflating: work/data/animal/val/7/rabbit_10060.jpg
#   inflating: work/data/animal/val/7/rabbit_10061.jpg
#   inflating: work/data/animal/val/7/rabbit_10062.jpg
#   inflating: work/data/animal/val/7/rabbit_10063.jpg
#   inflating: work/data/animal/val/7/rabbit_10064.jpg
#   inflating: work/data/animal/val/7/rabbit_10065.jpg
#   inflating: work/data/animal/val/7/rabbit_10066.jpg
#   inflating: work/data/animal/val/7/rabbit_10067.jpg
#   inflating: work/data/animal/val/7/rabbit_10068.jpg
#   inflating: work/data/animal/val/7/rabbit_10069.jpg
#   inflating: work/data/animal/val/7/rabbit_10070.jpg
#   inflating: work/data/animal/val/7/rabbit_10071.jpg
#   inflating: work/data/animal/val/7/rabbit_10072.jpg
#   inflating: work/data/animal/val/7/rabbit_10073.jpg
#   inflating: work/data/animal/val/7/rabbit_10074.jpg
#   inflating: work/data/animal/val/7/rabbit_10075.jpg
#   inflating: work/data/animal/val/7/rabbit_10076.jpg
#   inflating: work/data/animal/val/7/rabbit_10077.jpg
#   inflating: work/data/animal/val/7/rabbit_10078.jpg
#   inflating: work/data/animal/val/7/rabbit_10079.jpg
#   inflating: work/data/animal/val/7/rabbit_10080.jpg
#   inflating: work/data/animal/val/7/rabbit_10081.jpg
#   inflating: work/data/animal/val/7/rabbit_10082.jpg
#   inflating: work/data/animal/val/7/rabbit_10083.jpg
#   inflating: work/data/animal/val/7/rabbit_10084.jpg
#   inflating: work/data/animal/val/7/rabbit_10085.jpg
#   inflating: work/data/animal/val/7/rabbit_10086.jpg
#   inflating: work/data/animal/val/7/rabbit_10087.jpg
#   inflating: work/data/animal/val/7/rabbit_10088.jpg
#   inflating: work/data/animal/val/7/rabbit_10089.jpg
#   inflating: work/data/animal/val/7/rabbit_10090.jpg
#   inflating: work/data/animal/val/7/rabbit_10091.jpg
#   inflating: work/data/animal/val/7/rabbit_10092.jpg
#   inflating: work/data/animal/val/7/rabbit_10093.jpg
#   inflating: work/data/animal/val/7/rabbit_10094.jpg
#   inflating: work/data/animal/val/7/rabbit_10095.jpg
#   inflating: work/data/animal/val/7/rabbit_10096.jpg
#   inflating: work/data/animal/val/7/rabbit_10097.jpg
#   inflating: work/data/animal/val/7/rabbit_10098.jpg
#   inflating: work/data/animal/val/7/rabbit_10099.jpg
#   inflating: work/data/animal/val/7/rabbit_10100.jpg
#   inflating: work/data/animal/val/7/rabbit_10101.jpg
#   inflating: work/data/animal/val/7/rabbit_10102.jpg
#   inflating: work/data/animal/val/7/rabbit_10103.jpg
#   inflating: work/data/animal/val/7/rabbit_10104.jpg
#   inflating: work/data/animal/val/7/rabbit_10105.jpg
#   inflating: work/data/animal/val/7/rabbit_10106.jpg
#   inflating: work/data/animal/val/7/rabbit_10107.jpg
#   inflating: work/data/animal/val/7/rabbit_10108.jpg
#    creating: work/data/animal/val/8/
#   inflating: work/data/animal/val/8/german+shepherd_10001.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10002.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10003.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10004.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10005.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10006.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10007.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10008.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10009.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10010.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10011.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10012.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10013.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10014.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10015.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10016.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10017.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10018.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10019.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10020.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10021.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10022.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10023.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10024.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10025.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10026.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10027.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10028.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10029.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10030.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10031.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10032.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10033.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10034.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10035.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10036.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10037.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10038.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10039.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10040.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10041.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10042.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10043.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10044.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10045.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10046.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10047.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10048.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10049.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10050.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10051.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10052.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10053.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10054.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10055.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10056.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10057.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10058.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10059.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10060.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10061.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10062.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10063.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10064.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10065.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10066.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10067.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10068.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10069.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10070.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10071.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10072.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10073.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10074.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10075.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10076.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10077.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10078.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10079.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10080.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10081.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10082.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10083.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10084.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10085.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10086.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10087.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10088.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10089.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10090.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10091.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10092.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10093.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10094.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10095.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10096.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10097.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10098.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10099.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10100.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10101.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10102.jpg
#   inflating: work/data/animal/val/8/german+shepherd_10103.jpg
#    creating: work/data/animal/val/9/
#   inflating: work/data/animal/val/9/elephant_10001.jpg
#   inflating: work/data/animal/val/9/elephant_10002.jpg
#   inflating: work/data/animal/val/9/elephant_10003.jpg
#   inflating: work/data/animal/val/9/elephant_10004.jpg
#   inflating: work/data/animal/val/9/elephant_10005.jpg
#   inflating: work/data/animal/val/9/elephant_10006.jpg
#   inflating: work/data/animal/val/9/elephant_10007.jpg
#   inflating: work/data/animal/val/9/elephant_10008.jpg
#   inflating: work/data/animal/val/9/elephant_10009.jpg
#   inflating: work/data/animal/val/9/elephant_10010.jpg
#   inflating: work/data/animal/val/9/elephant_10011.jpg
#   inflating: work/data/animal/val/9/elephant_10012.jpg
#   inflating: work/data/animal/val/9/elephant_10013.jpg
#   inflating: work/data/animal/val/9/elephant_10014.jpg
#   inflating: work/data/animal/val/9/elephant_10015.jpg
#   inflating: work/data/animal/val/9/elephant_10016.jpg
#   inflating: work/data/animal/val/9/elephant_10017.jpg
#   inflating: work/data/animal/val/9/elephant_10018.jpg
#   inflating: work/data/animal/val/9/elephant_10019.jpg
#   inflating: work/data/animal/val/9/elephant_10020.jpg
#   inflating: work/data/animal/val/9/elephant_10021.jpg
#   inflating: work/data/animal/val/9/elephant_10022.jpg
#   inflating: work/data/animal/val/9/elephant_10023.jpg
#   inflating: work/data/animal/val/9/elephant_10024.jpg
#   inflating: work/data/animal/val/9/elephant_10025.jpg
#   inflating: work/data/animal/val/9/elephant_10026.jpg
#   inflating: work/data/animal/val/9/elephant_10027.jpg
#   inflating: work/data/animal/val/9/elephant_10028.jpg
#   inflating: work/data/animal/val/9/elephant_10029.jpg
#   inflating: work/data/animal/val/9/elephant_10030.jpg
#   inflating: work/data/animal/val/9/elephant_10031.jpg
#   inflating: work/data/animal/val/9/elephant_10032.jpg
#   inflating: work/data/animal/val/9/elephant_10033.jpg
#   inflating: work/data/animal/val/9/elephant_10034.jpg
#   inflating: work/data/animal/val/9/elephant_10035.jpg
#   inflating: work/data/animal/val/9/elephant_10036.jpg
#   inflating: work/data/animal/val/9/elephant_10037.jpg
#   inflating: work/data/animal/val/9/elephant_10038.jpg
#   inflating: work/data/animal/val/9/elephant_10039.jpg
#   inflating: work/data/animal/val/9/elephant_10040.jpg
#   inflating: work/data/animal/val/9/elephant_10041.jpg
#   inflating: work/data/animal/val/9/elephant_10042.jpg
#   inflating: work/data/animal/val/9/elephant_10043.jpg
#   inflating: work/data/animal/val/9/elephant_10044.jpg
#   inflating: work/data/animal/val/9/elephant_10045.jpg
#   inflating: work/data/animal/val/9/elephant_10046.jpg
#   inflating: work/data/animal/val/9/elephant_10047.jpg
#   inflating: work/data/animal/val/9/elephant_10048.jpg
#   inflating: work/data/animal/val/9/elephant_10049.jpg
#   inflating: work/data/animal/val/9/elephant_10050.jpg
#   inflating: work/data/animal/val/9/elephant_10051.jpg
#   inflating: work/data/animal/val/9/elephant_10052.jpg
#   inflating: work/data/animal/val/9/elephant_10053.jpg
#   inflating: work/data/animal/val/9/elephant_10054.jpg
#   inflating: work/data/animal/val/9/elephant_10055.jpg
#   inflating: work/data/animal/val/9/elephant_10056.jpg
#   inflating: work/data/animal/val/9/elephant_10057.jpg
#   inflating: work/data/animal/val/9/elephant_10058.jpg
#   inflating: work/data/animal/val/9/elephant_10059.jpg
#   inflating: work/data/animal/val/9/elephant_10060.jpg
#   inflating: work/data/animal/val/9/elephant_10061.jpg
#   inflating: work/data/animal/val/9/elephant_10062.jpg
#   inflating: work/data/animal/val/9/elephant_10063.jpg
#   inflating: work/data/animal/val/9/elephant_10064.jpg
#   inflating: work/data/animal/val/9/elephant_10065.jpg
#   inflating: work/data/animal/val/9/elephant_10066.jpg
#   inflating: work/data/animal/val/9/elephant_10067.jpg
#   inflating: work/data/animal/val/9/elephant_10068.jpg
#   inflating: work/data/animal/val/9/elephant_10069.jpg
#   inflating: work/data/animal/val/9/elephant_10070.jpg
#   inflating: work/data/animal/val/9/elephant_10071.jpg
#   inflating: work/data/animal/val/9/elephant_10072.jpg
#   inflating: work/data/animal/val/9/elephant_10073.jpg
#   inflating: work/data/animal/val/9/elephant_10074.jpg
#   inflating: work/data/animal/val/9/elephant_10075.jpg
#   inflating: work/data/animal/val/9/elephant_10076.jpg
#   inflating: work/data/animal/val/9/elephant_10077.jpg
#   inflating: work/data/animal/val/9/elephant_10078.jpg
#   inflating: work/data/animal/val/9/elephant_10079.jpg
#   inflating: work/data/animal/val/9/elephant_10080.jpg
#   inflating: work/data/animal/val/9/elephant_10081.jpg
#   inflating: work/data/animal/val/9/elephant_10082.jpg
#   inflating: work/data/animal/val/9/elephant_10083.jpg
#   inflating: work/data/animal/val/9/elephant_10084.jpg
#   inflating: work/data/animal/val/9/elephant_10085.jpg
#   inflating: work/data/animal/val/9/elephant_10086.jpg
#   inflating: work/data/animal/val/9/elephant_10087.jpg
#   inflating: work/data/animal/val/9/elephant_10088.jpg
#   inflating: work/data/animal/val/9/elephant_10089.jpg
#   inflating: work/data/animal/val/9/elephant_10090.jpg
#   inflating: work/data/animal/val/9/elephant_10091.jpg
#   inflating: work/data/animal/val/9/elephant_10092.jpg
#   inflating: work/data/animal/val/9/elephant_10093.jpg
#   inflating: work/data/animal/val/9/elephant_10094.jpg
#   inflating: work/data/animal/val/9/elephant_10095.jpg
#   inflating: work/data/animal/val/9/elephant_10096.jpg
#   inflating: work/data/animal/val/9/elephant_10097.jpg
#   inflating: work/data/animal/val/9/elephant_10098.jpg
#   inflating: work/data/animal/val/9/elephant_10099.jpg
#   inflating: work/data/animal/val/9/elephant_10100.jpg
#   inflating: work/data/animal/val/9/elephant_10101.jpg
#   inflating: work/data/animal/val/9/elephant_10102.jpg
#   inflating: work/data/animal/val/9/elephant_10103.jpg

# %% [markdown]
# ### 3.2 导入相关包

# %%
#导入包
import numpy as np
import os
import paddle
from paddle.io import Dataset, DataLoader
import paddle.nn as nn
import paddle.nn.functional as F
import paddle.fluid as fluid
from paddle.vision.datasets import DatasetFolder
import paddle.vision.transforms as transforms
from PIL import Image
import sys
import warnings
import bisect
import math
from collections import Counter
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
# Out:
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/layers/utils.py:26: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   def convert_to_list(value, n, name, dtype=np.int):
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/__init__.py:107: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import MutableMapping
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/rcsetup.py:20: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Iterable, Mapping
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/colors.py:53: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Sized
# 2025-04-22 23:59:13,092 - INFO - font search path ['/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf', '/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/afm', '/opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/pdfcorefonts']
# 2025-04-22 23:59:13,418 - INFO - generated new fontManager

# %% [markdown]
# ### 3.3 数据处理
# paddle.vision 为图像预处理、数据包装以及数据增强提供了许多有用的实用程序。
#
# 在这里，由于我们的数据是按类标签存储在文件夹中的，所以我们可以直接应用 paddle.vision.datasets.DatasetFolder 来包装数据。
#
# 详细信息，请参阅 paddlepaddle 官网。
#
# **你需要完成数据增强部分的代码。如对图片进行旋转或者缩放、裁剪等操作。**

# %%
# 在训练中进行数据增强很重要。
train_tfm = transforms.Compose([
    # 将图像大小调整为固定形状 (height = width = 128)
    transforms.Resize((128, 128)),
    # ---------- TODO ----------
    # 任务点1：数据增强
    # 在此处添加你的代码，进行数据增强
    transforms.RandomResizedCrop(128, scale=(0.8, 1.0)),  # 随机裁剪并缩放
    transforms.RandomHorizontalFlip(prob=0.5),               # 随机水平翻转
    # transforms.RandomVerticalFlip(prob=0.2),                 # 随机垂直翻转
    transforms.RandomRotation(degrees=15),                # 随机旋转
    transforms.ColorJitter(
        brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1
    ),  # 随机调整亮度、对比度、饱和度和色相
    transforms.ToTensor(),
])


# 我们不需要在测试和验证中进行扩充。
# 只需要调整 PIL 图像的大小并将其转换为 Tensor。
test_tfm = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
])

# %%
import os

#此处代码为构造dataloader函数。
IMG_EXTENSIONS = [
    ".jpg", ".JPG", ".jpeg", ".JPEG",
    ".png", ".PNG", ".ppm", ".PPM", ".bmp", ".BMP",
]

def is_image_file(filename):
    return any(filename.endswith(extension) for extension in IMG_EXTENSIONS)

def default_loader(path):
    return Image.open(path).convert("RGB")
    

def make_dataset(root, split, txtfile=None):
    images = []
    if txtfile is not None:
        ordertxt = open(txtfile)
        for line in ordertxt:
            data = line.strip()
            if is_image_file(data):
                imgpath = os.path.join(root,split,data)
            item = (imgpath, -1)
            images.append(item)
    else:
        root=os.path.join(root, split)
        for onelabel in os.listdir(root):
            newdir=os.path.join(root, onelabel)
            for img in os.listdir(newdir):
                imgpath=os.path.join(newdir,img)
                item = (imgpath, int(onelabel))
                images.append(item)
    return images

class ImageSet(Dataset):
    def __init__(self, root,split, transform=None, loader=default_loader,txtfile=None):
        self.samples = make_dataset(root,split,txtfile)
        self.root = root
        self.txtfile = txtfile
        self.transform = transform
        self.loader = loader

    def __getitem__(self, index):
        path, gt = self.samples[index]
        img = self.loader(path)

        if self.transform is not None:
            img = self.transform(img)
        return img, gt

    def __len__(self):
        return len(self.samples)

# %%
# 更大的batch size通常会提供更稳定的梯度，但是GPU 显存是有限的，batch size过大，显存可能加载不了。
batch_size = 256 
# 如果 out of memory,可以调小batch_size或者选用显存更大的GPU

# 构建数据集。数据集划分为训练集、验证集、公开测试集和私有测试集。私有测试集的标签在助教手中，助教将依据您对私有测试集的预测结果来打分。
# 代码main.ipynb要求一并上交，所以在实验报告中请如实作答。
    
data_root = 'work/data/animal/'
train_set = ImageSet(data_root,split="train", loader=lambda x: Image.open(x),transform=train_tfm)
val_set = ImageSet(data_root,split="val", loader=lambda x: Image.open(x), transform=test_tfm)
pub_test_set = ImageSet(data_root,split="pub_test", loader=lambda x: Image.open(x), transform=test_tfm)
pri_test_set = ImageSet(data_root,split="pri_test",txtfile="pri_test_only_name.txt",loader=lambda x: Image.open(x), transform=test_tfm)
semi_set = ImageSet(data_root,split="semi",txtfile="semi_only_name.txt",loader=lambda x: Image.open(x), transform=test_tfm)

train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, drop_last=False)
val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=False, drop_last=False)
pub_test_loader = DataLoader(pub_test_set, batch_size=batch_size, shuffle=False, drop_last=False)
pri_test_loader = DataLoader(pri_test_set, batch_size=batch_size, shuffle=False, drop_last=False)

# %% [markdown]
# ### 3.4 模型
# ### 3.4.1 CNN基础模型
# 基本模型由卷积层和全连接层构成。
#
# 由于彩色图像 (RGB) 有三个通道，因此网络的输入通道必须是3。输入大小为（3，128，128）。（128，128）为图片的宽和高。\
# 卷积网络的实现可调用nn.Conv2D（）函数，具体输入的参数请参数paddle使用文档。\
# nn.MaxPool2D()可对图片进行最大池化以提取重要特征。\
# 在输入全连接层之前，必须将特征图展平。经过全连接层，最后获得每个类的“logits”。
#
#
# 您可以在此处自由修改模型架构，以进一步提升效果。\
# \
# 注意事项：
# 使用互联网上任何模型都是允许的，但是，如果想使用常见的网络结构，如vgg等，请确保不要加载预训练的参数。\
# 另外，复杂的网络有过拟合的风险，当改变网络结构时，超参也有可能需要调整。\
# \
# 例如，如果您使用 ResNet-18 作为模型：
#
# model = paddle.vision.models.resnet18(pretrained=False) → 这是符合要求。
#
# model = paddle.models.resnet18(pretrained=True) → 这是不符合要求的

# %%
# class CNN(nn.Layer):
#     def __init__(self):
#         super(CNN, self).__init__()
#         # 常用模块的参数：
#         # paddle.nn.Conv2D(in_channels, out_channels, kernel_size, stride, padding)
#         # paddle.nn.MaxPool2D(kernel_size, stride, padding)

#         # input image size: [3, 128, 128]
#         # ---------- TODO ----------
#         # 任务点2：定义CNN架构
#         # 以下是一个简单的CNN架构，您可以在此处自由修改。当前的架构也可以直接运行，但效果无保障。
#         self.cnn_layers = nn.Sequential(
#             nn.Conv2D(3, 64, 3, 1, 1),
#             nn.ReLU(),
#             nn.MaxPool2D(2, 2, 0),

#             nn.Conv2D(64, 128, 3, 1, 1),
#             nn.ReLU(),
#             nn.MaxPool2D(2, 2, 0),

#             nn.Conv2D(128, 256, 3, 1, 1),
#             nn.ReLU(),
#             nn.MaxPool2D(4, 4, 0),
#         )
#         self.fc_layers = nn.Sequential(
#             nn.Linear(256 * 8 * 8, 256),
#             nn.ReLU(),
#             nn.Linear(256, 10)
#         )

#     def forward(self, x):
        
#         # input (x): [batch_size, 3, 128, 128]
#         # output: [batch_size, 10]

#         # 提取特征
#         x = self.cnn_layers(x)       
#         x = x.flatten(1)
#         # 特征通过全连接层转换得到最终的logits。
#         x = self.fc_layers(x)
#         return x

# # ---------- TODO ----------
# # 任务点3：自定义模型架构
# # 您可以在此处自由修改模型架构以进行进一步改进。如增加卷积层数等。
# # 如果您想使用一些众所周知的架构，例如 ResNet50，请确保不要加载预训练的权重。另外，复杂的模型有过拟合的风险。
# # 使用其他模型时，请同步修改任务点4中的模型初始化。
    
import paddle
import paddle.nn as nn

class CNN(nn.Layer):
    def __init__(self, num_classes=10, dropout_prob=0.3):
        super(CNN, self).__init__()
        # 特征提取部分
        self.features = nn.Sequential(
            # 第1个卷积块：3->32通道，128x128->64x64
            nn.Conv2D(in_channels=3, out_channels=32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2D(32),
            nn.ReLU(),
            nn.MaxPool2D(kernel_size=2, stride=2),
            
            # 第2个卷积块：32->64通道，64x64->32x32
            nn.Conv2D(32, 64, 3, 1, 1),
            nn.BatchNorm2D(64),
            nn.ReLU(),
            nn.MaxPool2D(2, 2),
            
            # 第3个卷积块：64->128通道，32x32->16x16
            nn.Conv2D(64, 128, 3, 1, 1),
            nn.BatchNorm2D(128),
            nn.ReLU(),
            nn.MaxPool2D(2, 2),
            
            # 第4个卷积块：128->256通道，16x16->8x8
            nn.Conv2D(128, 256, 3, 1, 1),
            nn.BatchNorm2D(256),
            nn.ReLU(),
            nn.MaxPool2D(2, 2),
            
            # 第5个卷积块：256->512通道，8x8->4x4
            nn.Conv2D(256, 512, 3, 1, 1),
            nn.BatchNorm2D(512),
            nn.ReLU(),
            nn.MaxPool2D(2, 2)
        )
        
        # 分类器部分
        self.classifier = nn.Sequential(
            nn.Linear(512 * 4 * 4, 1024),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = paddle.flatten(x, start_axis=1)
        x = self.classifier(x)
        return x

# Usage example:
# model = CNN(num_classes=10)

# %% [markdown]
# ### 3.4.2 VisionTransformer模型
# VisionTransformer模型总体上由 PatchEmbed层 , depth 个堆叠的 自注意力Block 和最后的 分类头 组成。\
# 如果你想尝试使用VisionTransformer来达到更好的效果，助教已经帮你实现好了整个VisionTransformer \
# 但是你还需要探索一组合适的参数用于VisionTransformer.__init__，有一定的难度，建议最后尝试。 \
# \
# 注意：如果要运行VisionTransformer模型，请确保已经完成 ViT.py 文件中的5个TODO（任务点7）。

# %%
# ---------- TODO ----------
# 任务点7：实现ViT模型（补全 ViT.py 文件中代码），并调整ViT参数

# 参数初始化配置
trunc_normal_ = nn.initializer.TruncatedNormal(std=.02)
zeros_ = nn.initializer.Constant(value=0.)
ones_ = nn.initializer.Constant(value=1.)


from ViT import PatchEmbed, Block, Identity
class VisionTransformer(nn.Layer):
    def __init__(self,
                 img_size=128,
                 patch_size=16,
                 in_chans=3,
                 class_dim=10,
                 embed_dim=768,
                 depth=4,
                 num_heads=4,
                 mlp_ratio=4,
                 qkv_bias=False,
                 qk_scale=None,
                 drop_rate=0.,
                 attn_drop_rate=0.,
                 drop_path_rate=0.,
                 norm_layer='nn.LayerNorm',
                 epsilon=1e-5,
                 **args):
        super().__init__()
        self.class_dim = class_dim

        self.num_features = self.embed_dim = embed_dim
        # 图片分块和降维，块大小为patch_size，最终块向量维度为768
        self.patch_embed = PatchEmbed(
            img_size=img_size,
            patch_size=patch_size,
            in_chans=in_chans,
            embed_dim=embed_dim)
        # 分块数量
        num_patches = self.patch_embed.num_patches
        # 可学习的位置编码
        self.pos_embed = self.create_parameter(shape=(1, num_patches + 1, embed_dim), default_initializer=zeros_)
        self.add_parameter("pos_embed", self.pos_embed)
        # 人为追加class token，并使用该向量进行分类预测
        self.cls_token = self.create_parameter(shape=(1, 1, embed_dim), default_initializer=zeros_)
        self.add_parameter("cls_token", self.cls_token)
        self.pos_drop = nn.Dropout(p=drop_rate)

        dpr = np.linspace(0, drop_path_rate, depth)
        # transformer
        self.blocks = nn.LayerList([
            Block(
                dim=embed_dim,
                num_heads=num_heads,
                mlp_ratio=mlp_ratio,
                qkv_bias=qkv_bias,
                qk_scale=qk_scale,
                drop=drop_rate,
                attn_drop=attn_drop_rate,
                drop_path=dpr[i],
                norm_layer=norm_layer,
                epsilon=epsilon) for i in range(depth)
        ])

        self.norm = eval(norm_layer)(embed_dim, epsilon=epsilon)

        # Classifier head
        self.head = nn.Linear(embed_dim,class_dim) if class_dim > 0 else Identity()

        trunc_normal_(self.pos_embed)
        trunc_normal_(self.cls_token)
        self.apply(self._init_weights)
    # 参数初始化
    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            trunc_normal_(m.weight)
            if isinstance(m, nn.Linear) and m.bias is not None:
                zeros_(m.bias)
        elif isinstance(m, nn.LayerNorm):
            zeros_(m.bias)
            ones_(m.weight)

    def forward_features(self, x):

        B = paddle.shape(x)[0]
        # 将图片分块，并调整每个块向量的维度
        x = self.patch_embed(x)

        # 将class token与前面的分块进行拼接
        cls_tokens = self.cls_token.expand((B, -1, -1))
        x = paddle.concat((cls_tokens, x), axis=1)
        # 将编码向量中加入位置编码
        x = x + self.pos_embed
        x = self.pos_drop(x)
        # 堆叠 transformer 结构
        for blk in self.blocks:
            x = blk(x)
        # LayerNorm
        x = self.norm(x)
        # 提取分类 tokens 的输出
        return x[:, 0]

    def forward(self, x):
        # 获取图像特征
        x = self.forward_features(x)
        # 图像分类
        x = self.head(x)
        return x

# %% [markdown]
# ### 3.5 训练
# ### 3.5.1 一些性能相关的提示
# 1 基于最基础的代码，不增加任何数据增强，不修改任何参数，batch_size = 256 跑通，训练10个epoch， best_val_acc大约 0.508\
# 2 数据增强+修改提供的CNN网络结构+调整学习率，训练35epoch  best_val_acc大约 0.72-0.73 \
# 3 数据增强+修改提供的CNN网络结构+调整学习率+半监督数据集  性能微量up \
# 4 尝试使用VIT或者更适合小数据集的VIT变体？ 自由探索！\
# 5 推荐将模型训练到一定的效果后再考虑半监督，不然会误导模型

# %%
# 固定 random seed
def same_seeds(seed):
    paddle.seed(seed)
    np.random.seed(seed)

same_seeds(0)
do_semi = False
init_model=True

# %%
import paddle.vision.models

# 加载模型 开始训练
if init_model:
    # ---------- TODO ----------
    # 任务点4：模型初始化
    # 模型初始化，请修改这里，使用简单CNN或VisionTransformer，也可以使用其他模型，比如ResNet50等。
    # model=CNN()
    # model = VisionTransformer()
    model = paddle.vision.models.resnet18(pretrained=False)
    # model = paddle.vision.models.resnet34(pretrained=False)

n_epochs = 100
learning_rate = 0.0002
work_path = 'work/model'
# 损失函数cross-entropy
criterion = nn.CrossEntropyLoss()

# 初始化优化器，可以微调一些超参数，比如学习率。
grad_norm = paddle.nn.ClipGradByGlobalNorm(clip_norm=10)
optimizer = paddle.optimizer.Adam(parameters=model.parameters(), learning_rate=learning_rate, weight_decay=1e-3, grad_clip=grad_norm)

# best_acc = 0.0
best_acc = 0.7
val_acc = 0.0
loss_record = {'train': {'loss': [], 'iter': []}, 'val': {'loss': [], 'iter': []}}   # for recording loss
acc_record = {'train': {'acc': [], 'iter': []}, 'val': {'acc': [], 'iter': []}}      # for recording accuracy
loss_iter = 0
acc_iter = 0

if do_semi:
    this_train_loader = semi_train_loader
    print("do_semi")
else:
    this_train_loader = train_loader


print("start train")
for epoch in range(n_epochs):
    model.train()
    train_num = 0.0
    train_loss = 0.0
    val_num = 0.0
    val_loss = 0.0
    accuracy_manager = paddle.metric.Accuracy()
    val_accuracy_manager = paddle.metric.Accuracy()

    for batch_id, data in enumerate(this_train_loader):
        x_data, y_data = data

        if y_data.dim()==1:
            y_data = paddle.unsqueeze(y_data, axis=1)
        logits = model(x_data)
        # print("43_y_data.shape",y_data.shape)
        loss = criterion(logits, y_data)
        acc = paddle.metric.accuracy(logits, y_data)
        accuracy_manager.update(acc)
        if batch_id % 10 == 0:
            loss_record['train']['loss'].append(loss.numpy())
            loss_record['train']['iter'].append(loss_iter)
            loss_iter += 1
            print("epoch: {}, batch_id: {}, loss is: {}, acc is: {}".format(epoch, batch_id, loss.numpy(), acc.numpy()))
        
        loss.backward()
        optimizer.step()
        optimizer.clear_grad()
        train_loss += loss
        train_num += len(y_data)

    
    total_train_loss = (train_loss / train_num) * batch_size
    train_acc = accuracy_manager.accumulate()
    acc_record['train']['acc'].append(train_acc)
    acc_record['train']['iter'].append(acc_iter)
    acc_iter += 1
    print("#===epoch: {}, train loss is: {}, train acc is: {:2.2f}%===#".format(epoch, total_train_loss.numpy(), train_acc*100))

    # ---------- Validation ----------
    # 确保模型处于value模式，以便某些仅仅适用于训练的操作（如 dropout）被禁用并正常工作。
    model.eval()

    # 分批迭代验证集。
    for batch_id, data in enumerate(val_loader):
        # 一个batch由图像数据和相应的标签组成。
        x_data, y_data = data
        
        if y_data.dim()==1:
            y_data = paddle.unsqueeze(y_data, axis=1)
        with paddle.no_grad():
          logits = model(x_data)
        loss = criterion(logits, y_data)
        # 计算每个batch的 the accuracy 
        acc = paddle.metric.accuracy(logits, y_data)
        val_accuracy_manager.update(acc)
        # 记录 loss and accuracy.
        val_loss += loss
        val_num += len(y_data)

    
    total_val_loss = (val_loss / val_num) * batch_size
    loss_record['val']['loss'].append(total_val_loss.numpy())
    loss_record['val']['iter'].append(loss_iter)
    val_acc = val_accuracy_manager.accumulate()
    acc_record['val']['acc'].append(val_acc)
    acc_record['val']['iter'].append(acc_iter)
    print("#===epoch: {}, val loss is: {}, val acc is: {:2.2f}%===#".format(epoch, total_val_loss.numpy(), val_acc*100))
    # ===================save====================
    if val_acc > best_acc:
        best_acc = val_acc
        paddle.save(model.state_dict(), os.path.join(work_path, 'best_model.pdparams'))
        paddle.save(optimizer.state_dict(), os.path.join(work_path, 'best_optimizer.pdopt'))
        print(f"saved,best_val_acc={best_acc}")


paddle.save(model.state_dict(), os.path.join(work_path, 'final_model.pdparams'))
paddle.save(optimizer.state_dict(), os.path.join(work_path, 'final_optimizer.pdopt'))
# Out:
# do_semi
# start train
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_506/148348820.py in <module>
#      51         if y_data.dim()==1:
#      52             y_data = paddle.unsqueeze(y_data, axis=1)
# ---> 53         logits = model(x_data)
#      54         # print("43_y_data.shape",y_data.shape)
#      55         loss = criterion(logits, y_data)
#
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py in __call__(self, *inputs, **kwargs)
#     900                 self._built = True
#     901
# --> 902             outputs = self.forward(*inputs, **kwargs)
#     903
#     904             for forward_post_hook in self._forward_post_hooks.values():
#
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/vision/models/resnet.py in forward(self, x)
#     239         x = self.conv1(x)
#     240         x = self.bn1(x)
# --> 241         x = self.relu(x)
#     242         x = self.maxpool(x)
#     243         x = self.layer1(x)
#
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py in __call__(self, *inputs, **kwargs)
#     900                 self._built = True
#     901
# --> 902             outputs = self.forward(*inputs, **kwargs)
#     903
#     904             for forward_post_hook in self._forward_post_hooks.values():
#
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/nn/layer/activation.py in forward(self, x)
#     433
#     434     def forward(self, x):
# --> 435         return F.relu(x, self._name)
#     436
#     437     def extra_repr(self):
#
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/nn/functional/activation.py in relu(x, name)
#     526
#     527     if in_dygraph_mode():
# --> 528         return core.ops.relu(x)
#     529
#     530     check_variable_and_dtype(x, 'x', ['float16', 'float32', 'float64'], 'relu')
#
# KeyboardInterrupt:

# %% [markdown]
# ### 3.5.2 半监督学习
# 如果想要更进一步提升效果，需要完成下面的函数“get_pseudo_labels”中空缺的内容。该函数用于半监督学习。 具体而言，需要对未标记的数据进行预测，然后获得置信度大的预测结果作为伪标签来扩充数据集，这样模型会获得更好的表现。

# %%
# from paddle.io import TensorDataset

# def get_pseudo_labels(dataset, model, threshold=0.65):
#     # 此函数使用给定模型生成数据集的伪标签。
#     # 它返回一个 DatasetFolder 实例，其中包含预测图片logits置信度超过给定阈值的图片。
  
#     # 构造一个数据加载器。
#     data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=False, drop_last=False)

#     # 确保模型处于 eval 模型）禁止训练。
#     model.eval()
#     # 定义softmax函数
#     softmax = nn.Softmax(axis=-1)
#     # 训练
#     for batch_id, data in enumerate(data_loader):
#         batch_img, _ = data
#         # 使用 torch.no_grad() 加速了前向过程。
#         with paddle.no_grad():
#             logits = model(batch_img)

#         # 通过对 logits 应用 softmax 来获得概率分布。
#         probs = softmax(logits)
#         # print(probs.shape)
#         # ---------- TODO ----------
#         # 任务点5：半监督数据集
#         # 过滤数据并构建一个新的数据集。提示：使用TensorDataset
#         # 计算每个样本的最大概率和对应的伪标签
#         max_probs = paddle.max(probs, axis=1)
#         pred_labels = paddle.argmax(probs, axis=1)

#         # 过滤置信度高于阈值的样本
#         mask = max_probs >= threshold
#         selected_images = batch_img[mask]
#         selected_labels = pred_labels[mask]

#         # 收集符合条件的样本
#         if selected_labels.shape[0] > 0:
#             pseudo_images.append(selected_images)
#             pseudo_labels.append(selected_labels)
    
#     # 合并所有批次的样本
#     if pseudo_images:
#         pseudo_images = paddle.concat(pseudo_images)
#         pseudo_labels = paddle.concat(pseudo_labels)
#     else:
#         # 若无符合样本，返回空数据集
#         pseudo_images = paddle.zeros([0] + list(batch_img.shape[1:]), dtype=batch_img.dtype)
#         pseudo_labels = paddle.zeros([0], dtype=paddle.int64)
    
#     # 构建包含伪标签的数据集
#     pseudo_dataset = TensorDataset([pseudo_images, pseudo_labels])
    
#     return pseudo_dataset

from paddle.io import TensorDataset

def get_pseudo_labels(dataset, model, threshold=0.65):
    # 此函数使用给定模型生成数据集的伪标签。
    # 它返回一个 DatasetFolder 实例，其中包含预测图片logits置信度超过给定阈值的图片。

    # 构造一个数据加载器。
    data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=False, drop_last=False)

    # 确保模型处于 eval 模型）禁止训练。
    model.eval()
    # 定义softmax函数
    softmax = nn.Softmax(axis=-1)
    pseudo_images = []
    pseudo_labels = []
    # 遍历数据集
    for batch_id, data in enumerate(data_loader):
        batch_img, _ = data
        # 使用 paddle.no_grad() 加速前向过程。
        with paddle.no_grad():
            logits = model(batch_img)

        # 通过对 logits 应用 softmax 来获得概率分布。
        probs = softmax(logits)
        # 获取每张图片的最大概率及其对应的类别
        max_probs = paddle.max(probs, axis=1)
        predicted_labels = paddle.argmax(probs, axis=1)

        for i in range(len(max_probs)):
            if max_probs[i] >= threshold:
                pseudo_images.append(batch_img[i].numpy())  # 保存图片
                pseudo_labels.append(predicted_labels[i].numpy())  # 保存伪标签

    # 构造新的数据集
    pseudo_images = paddle.to_tensor(pseudo_images)
    pseudo_labels = paddle.to_tensor(pseudo_labels)
    pseudo_dataset = TensorDataset([pseudo_images, pseudo_labels])
        # --------------------------------
    return pseudo_dataset

# %% [markdown]
# 当你需要进行半监督训练时，请取消以下单元格的注释，并修改以下的do_semi为True，构建semi_train_loader后，再次运行模型训练单元格即可 \
# \
# 注意：
# - 使用半监督的前提条件是你的模型已经可以取得一定的效果 \
# - 当你进行半监督训练时，你的模型已经是训练过的，所以,你应该调整相关参数（n_epochs,learning_rate)

# %%
do_semi=True
threshold =0.75
if do_semi:
    # ---------- TODO ----------
    # 任务点6：半监督数据集
    # 使用经过训练的模型获取未标记数据的伪标签（提示：调用get_pseudo_labels函数）。
    semi_train_dataset= get_pseudo_labels(semi_set, model, threshold=threshold)
    # --------------------------------
    # 构造一个新的数据集和一个用于训练的数据加载器。
    semi_train_loader = DataLoader(semi_train_dataset, batch_size=batch_size, shuffle=True, drop_last=False)
    init_model=False
    # 置init_model为False，确保再次再次运行模型训练单元格时，不会重新初始化模型
# Out:
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/tensor/creation.py:143: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if data.dtype == np.object:

# %%
#画图
def plot_learning_curve(record, title='loss', ylabel='CE Loss'):
    ''' Plot learning curve of your CNN '''
    maxtrain = max(map(float, record['train'][title]))
    maxval = max(map(float, record['val'][title]))
    ymax = max(maxtrain, maxval) * 1.1
    mintrain = min(map(float, record['train'][title]))
    minval = min(map(float, record['val'][title]))
    ymin = min(mintrain, minval) * 0.9
    total_steps = len(record['train'][title])
    x_1 = list(map(int, record['train']['iter']))
    x_2 = list(map(int, record['val']['iter']))
    figure(figsize=(10, 6))
    plt.plot(x_1, record['train'][title], c='tab:red', label='train')
    plt.plot(x_2, record['val'][title], c='tab:cyan', label='val')
    plt.ylim(ymin, ymax)
    plt.xlabel('Training steps')
    plt.ylabel(ylabel)
    plt.title('Learning curve of {}'.format(title))
    plt.legend()
    plt.show()

# %%
plot_learning_curve(loss_record, title='loss', ylabel='CE Loss')
# Out:
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:2349: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   if isinstance(obj, collections.Iterator):
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:2366: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   return list(data) if isinstance(data, collections.MappingView) else data

# %%
plot_learning_curve(acc_record, title='acc', ylabel='Accuracy')
# Out:
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:2349: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   if isinstance(obj, collections.Iterator):
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:2366: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   return list(data) if isinstance(data, collections.MappingView) else data

# %% [markdown]
# ### 3.5测试和提交
# 对于测试，我们需要确保模型处于 eval 模式，并且数据集的顺序不应该被打乱（test_loader 中的“shuffle=False”）。
#
# 将预测保存到 CSV 文件中。csv文件需要被提交，这是我们测试模型效果的重要依据。
#
# 最后上交的文件夹中包括此jupyter文件（后缀为ipynb的文件），预测结果predict.csv文件，以及实验报告和问答题的答案。

# %%
# 确保模型处于eval模式。
# 初始化一个列表来存储预测。
predictions = []
model_state_dict = paddle.load(os.path.join(work_path, 'best_model.pdparams'))
# optimizer_state_dict = paddle.load('work/model/best_model.pdopt')
model.set_state_dict(model_state_dict)
# optimizer.set_state_dict(optimizer_state_dict)

test_num = 0.0
test_loss = 0.0

model.eval()
test_accuracy_manager = fluid.metrics.Accuracy()
# 在公开测试集上进行测试
for batch_id, data in enumerate(pub_test_loader):
    x_data, y_data = data
    labels = paddle.unsqueeze(y_data, axis=1)
    
    # ===================forward=====================
    # 在测试中不需要梯度。
    # 使用 paddle.no_grad() 加速前进过程。
    with paddle.no_grad():
        predicts = model(x_data)
        loss = criterion(predicts, y_data)
    # ==================calculate acc================
    acc = paddle.metric.accuracy(predicts, labels)
    test_accuracy_manager.update(value = acc.numpy(), weight = len(y_data))

    test_loss += loss
    test_num += len(y_data)

test_acc = test_accuracy_manager.eval()
total_test_loss = (test_loss / test_num) * batch_size
print("test loss is: {}, test acc is: {}".format(total_test_loss.numpy(), test_acc))
# Out:
# test loss is: [1.3003538], test acc is: [0.7178457]

# %%
# 在私有测试集上进行测试
for batch_id, data in enumerate(pri_test_loader):
    x_data, y_data = data
    with paddle.no_grad():
        logits = model(x_data)
    predictions.extend(paddle.argmax(logits, axis=1).cpu().numpy().tolist())

# 将私有测试集的预测结果保存到文件predict.csv中
with open("./predict.csv", "w") as f:
    f.write("Id,Category\n")
    for i, pred in  enumerate(predictions):
         f.write(f"{i},{pred}\n")

# %% [markdown]
# 请点击[此处](https://ai.baidu.com/docs#/AIStudio_Project_Notebook/a38e5576)查看本环境基本用法.  <br>
# Please click [here ](https://ai.baidu.com/docs#/AIStudio_Project_Notebook/a38e5576) for more detailed instructions.
